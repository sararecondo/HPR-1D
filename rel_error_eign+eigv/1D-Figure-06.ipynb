# %% [markdown]
# Bilayer unit domain. Sigma optimisation

# %%
try:
    import dolfinx
except ImportError:
    # !wget "https://fem-on-colab.github.io/releases/fenicsx-install-release-complex.sh" -O "/tmp/fenicsx-install.sh" && bash "/tmp/fenicsx-install.sh"
    import dolfinx

# %%
import matplotlib.pyplot as plt

try:
	if "science" not in plt.style.available:
		try:
			import scienceplots  # registers styles if installed
		except Exception:
			# Install SciencePlots (registers the 'science' style) and import it
			get_ipython().run_line_magic('pip', 'install -q SciencePlots')
			import scienceplots  # noqa: F401
	plt.style.use(["science", "grid"])
except Exception as e:
	# If anything fails, fall back to a commonly available style
	print("Warning: 'science' style not available. Using 'seaborn' instead. Error:", e)
	plt.style.use("seaborn")

# %%
# Importing libraries
import matplotlib.pyplot as plt
from matplotlib import ticker
import numpy as np
from mpi4py import MPI
from ufl import (
    inner,
    grad,
    conj,
    TrialFunction,
    TestFunction,
    as_matrix,
    as_vector,
    dot,
    Or,
    Measure,
    conditional,
    SpatialCoordinate,
    dx,
)
from dolfinx.mesh import locate_entities_boundary, create_interval, locate_entities, meshtags
from dolfinx.fem import FunctionSpace, Function, functionspace, Function, dirichletbc, locate_dofs_topological, petsc, form, assemble_matrix, assemble_scalar
import basix
from dolfinx.geometry import bb_tree
from dolfinx import geometry
from petsc4py.PETSc import ScalarType
from slepc4py.SLEPc import EPS

# %% [markdown]
# Domain, PML, refinement and physical configurations

# %%
# Define simulation parameters
# Mesh configuration
h = [0.125/2,   # N=1
      0.125/4,   # N=2
      0.125/8,] # N=3
N=[1,2,3]  # Mesh refinement levels
# Domain configuration
Lx = 1. # fluid domain length (without PML)
l_inner=Lx/2

# Physical configuration
rho_media_1 = 1. # kg/m^3 
vel_media_1 = 2.   # m/s
rho_media_2 = 1. # kg/m^3 
vel_media_2 = 1.   # m/s

# Define the density and velocity functions  
def rho_function(x):    
    return np.where(x[0] > l_inner, rho_media_2,rho_media_1)

def vel_function(x):    
    return np.where(x[0] > l_inner, vel_media_2,vel_media_1)

# PML configuration
pml_thickness = Lx/4

# Solver configuration
requested_eigenvalues_number = 15 # Number of eigenvalues to compute

degree=[2,1]  # Polynomial degree for pressure and velocity

target=[-12.56j, 
        -50.26j] # Shifts for the eigensolvers

pml_profile = "piecewise"  # 'quadratic' 'singular'

match pml_profile:
    case 'piecewise':
        sigma_sweep=sigma_sweep = np.arange(1, 102)  #np.linspace(1., 101., 21) #piecewise
    case 'quadratic':
        sigma_sweep=sigma_sweep = np.arange(50, 151) #np.linspace(1., 201., 21) #quadratic
    case 'singular':
        sigma_sweep=sigma_sweep = np.arange(0.5, 3.1, 0.5) #np.linspace(0.1, 3.1, 21)

# %% [markdown]
# Solver configuration and computing

# %%
def get_configured_problem(mesh, degrees, sigma_x, target):
    # Initialize dictionaries
    dof = {}
    solver_dict={}
    V_dict={}
    Q_dict={}

    # Define finite element spaces
    p_fe_type = basix.ufl.element(family="Lagrange", cell=mesh.basix_cell(), degree=degrees[0])
    v_fe_type = basix.ufl.element(family="DG", cell=mesh.basix_cell(), degree=degrees[1], shape=(mesh.geometry.dim,))
    FE = {"p": p_fe_type, "v": v_fe_type}

    # Create a submesh of PML associated cells
    tdim = mesh.topology.dim

    # Identify the fluid cells
    # fluid_cells = locate_entities(mesh, tdim, lambda x: x[0] <= Lx)

    # Create function spaces for mesh and submesh
    Q = functionspace(mesh,FE["p"])
    V = functionspace(mesh, FE["v"])

    # Dictionaries to store the number of dofs
    dof["p"] = Q.dofmap.index_map.size_global
    dof["v"] = V.dofmap.index_map.size_global

    # Boundary conditions application (for pressure)
    bc = []
    facets = locate_entities_boundary(mesh, 0, lambda x: np.isclose(x[0], 0.0))
    o_boundary_dofs = locate_dofs_topological(Q, 0, facets)  # the dimension is related to mesh entity where dofs are located

    # Setting to zero located dofs related to boundaries
    u_d = Function(Q)
    u_d.x.array[:] = 0.0  # Asign Dirichlet condition value
    bc.append(dirichletbc(u_d, o_boundary_dofs))

    facets = locate_entities_boundary(mesh, 0, lambda x: np.isclose(x[0], Lx+pml_thickness))
    o_boundary_dofs = locate_dofs_topological(Q, 0, facets)  # the dimension is related to mesh entity where dofs are located

    # Define the subdomains using a Python function
    TOL = 1e-6
    def pml_domain(x):
        """Returns True for points in (Lx, Lx + pml_thickness]"""
        return x[0] > Lx - TOL

    # Get topology dimension
    tdim = mesh.topology.dim

    # Locate cells in each subdomain
    pml_cells = locate_entities(mesh, tdim, pml_domain)

    # Create a meshtag to mark the subdomains
    num_cells = mesh.topology.index_map(tdim).size_local
    cell_markers = np.ones(num_cells, dtype=np.int32) # Physical domain tag=1
    cell_markers[pml_cells] = 2       # PML domain tag=2

    cell_tags = meshtags(mesh, tdim, np.arange(num_cells, dtype=np.int32), cell_markers)

    # Now you can use these tags for integration measures
    dx = Measure("dx", domain=mesh, subdomain_data=cell_tags)

    # Setting to zero located dofs related to boundaries
    u_d = Function(Q)
    u_d.x.array[:] = 0.0  # Asign Dirichlet condition value
    bc.append(dirichletbc(u_d, o_boundary_dofs))

    # Interpolates the density and velocity functions
    W = functionspace(mesh, ("DG", 0))
    rho = Function(W)
    rho.interpolate(rho_function)
    c = Function(W)
    c.interpolate(vel_function)

    # Spatial Coordinate is updated for the actual mesh
    x = SpatialCoordinate(mesh)

    # Variation formulation definition
    p = TrialFunction(Q)
    v = TrialFunction(V)
    q = TestFunction(Q)
    w = TestFunction(V)

    # Define the variational forms
    a = form(
        [
            [sigma_x(x) / (rho * c**2) * p * conj(q) * dx(2), -1 * inner(v, grad(q)) * dx],
            [inner(grad(p), w) * dx, sigma_x(x) * rho * inner(v, w) * dx(2)],
        ]
    )
    b = form(
        [
            [1.0 / (rho * c**2) * p * conj(q) * dx, None],
            [None, rho * inner(v, w) * dx],
        ]
    )
    # Assemble matrices
    A = petsc.assemble_matrix_block(a, bcs=bc)
    A.assemble()
    B = petsc.assemble_matrix_block(b, bcs=bc)
    B.assemble()

    # SLEPc solver configuration for linear eigenvalue problem (A x =\lambda x B)
    solver = EPS().create()
    solver.setOperators(-A, B)
    solver.setType("arnoldi")
    solver.setWhichEigenpairs(9)  # TARGET_IMAGINARY = 9, TARGET_MAGNITUDE = 7, TARGET_REAL = 8
    solver.setDimensions(
        requested_eigenvalues_number,
        4 * requested_eigenvalues_number,
        4 * requested_eigenvalues_number,
    )
    solver.setTolerances(1e-16, 100)
    st = solver.getST()
    st.setType("sinvert")  # Applying spectral transformation "shift and invert"
    solver.setTarget(target)
    solver.solve()
    n_eigs_converged_quadratic = solver.getConverged()

    return solver, mesh, Q, V, dof

# %%
def assign_eigenvector_to_functions(vrA, p_h, v_h, dof):
    """
    Reparte o vector eigenvector 'vrA' entre p_h e v_h
    e normaliza no punto 'normalize_at'.
    """

    # --- separar as partes do autovector ---
    p_vals = vrA[:dof["p"]]
    v_vals = vrA[dof["p"]:]

    # asignar
    p_h.x.array[:] = p_vals
    v_h.x.array[:] = v_vals

    return p_h, v_h

# %%
def get_exact_eigenpair(selected_index, Q, V, x_hat):
    exact_physical_eigs_function= lambda n: vel_media_1 / l_inner * np.arctan(-1j * (vel_media_2 * rho_media_2) / (vel_media_1 * rho_media_1))+ n * np.pi * vel_media_1 / l_inner
    w=exact_physical_eigs_function(selected_index)

    # Función de presión en el primer medio
    p_1 = lambda x: np.sin(w * x / vel_media_1)

    # Valor de p_1 en la interfaz
    p_l_inner = p_1(l_inner)

    # Función de presión en el segundo medio, continua
    p_2 = lambda x: p_l_inner * np.exp(1j * w / vel_media_2 * (x_hat(x, w) - l_inner))

    # Función de presión completa
    p = lambda x: p_1(x[0]) + (x[0] >= l_inner) * (p_2(x[0]) - p_1(x[0]))

    # Velocidad en el primer medio
    def v_1(x):
        return ((-1j/(rho_media_1*vel_media_1)) * np.cos(w * x / vel_media_1))

    # Velocidad en el segundo medio, continua con la interfaz
    def v_2(x):
        return p_1(l_inner)/(rho_media_2*vel_media_2) * np.exp(1j * w / vel_media_2 * (x_hat(x, w) - l_inner))

    # Función de velocidad completa
    v = lambda x: v_1(x[0]) + (x[0] >= l_inner) * (v_2(x[0]) - v_1(x[0]))

    p_ex = Function(Q, name="p_ex")
    p_ex.interpolate(p)

    v_ex = Function(V, name="v_ex")
    v_ex.interpolate(v)

    return [w, p_ex, v_ex]

# %%
def eigenvector_L2_error_physical(u_num, u_exact, Lx, mesh):
    """
    Erro relativo L2 só no dominio físico [0, Lx] en DOLFINx 0.9.
    Alinea fase/signo antes de medir o erro.
    """

    import numpy as np
    import ufl
    from ufl import inner
    from dolfinx.mesh import locate_entities, meshtags
    from dolfinx.fem import form, assemble_scalar

    
    tdim = mesh.topology.dim
    # Define the subdomains using a Python function
    TOL = 1e-6
    def fluid_domain(x):
        """Returns True for points in [0, Lx]"""
        return np.logical_and(x[0] >= 0, x[0] < Lx + TOL)
    
    # --- 1) Localizar celas físicas ---
    cells_phys = locate_entities(
        mesh, tdim,
        fluid_domain
    )

    if len(cells_phys) == 0:
        raise RuntimeError("Non se detectaron celas na rexión física [0, Lx].")

    # Asignar etiqueta 1
    values = np.full(len(cells_phys), 1, dtype=np.int32)
    mt = meshtags(mesh, tdim, cells_phys, values)

    # Medida restrinxida
    dx_phys = ufl.Measure("dx", domain=mesh, subdomain_data=mt)
    
    # --- 3) Norma L2 do erro no dominio físico ---
    diff = u_num - u_exact

    num = np.sqrt(assemble_scalar(form(inner(diff, diff) * dx_phys(1))))
    den = np.sqrt(assemble_scalar(form(inner(u_exact, u_exact) * dx_phys(1))))

    return num / den

# %%
def get_exact_eigenpair(selected_index, Q, V, x_hat):
    exact_physical_eigs_function= lambda n: vel_media_1 / l_inner * np.arctan(-1j * (vel_media_2 * rho_media_2) / (vel_media_1 * rho_media_1))+ n * np.pi * vel_media_1 / l_inner
    w=exact_physical_eigs_function(selected_index)

    # Función de presión en el primer medio
    p_1 = lambda x: np.sin(w * x / vel_media_1)

    # Valor de p_1 en la interfaz
    p_l_inner = p_1(l_inner)

    # Función de presión en el segundo medio, continua
    p_2 = lambda x: p_l_inner * np.exp(1j * w / vel_media_2 * (x_hat(x, w) - l_inner))

    # Función de presión completa
    p = lambda x: p_1(x[0]) + (x[0] >= l_inner) * (p_2(x[0]) - p_1(x[0]))

    # Velocidad en el primer medio
    def v_1(x):
        return ((-1j/(rho_media_1*vel_media_1)) * np.cos(w * x / vel_media_1))

    # Velocidad en el segundo medio, continua con la interfaz
    def v_2(x):
        return p_1(l_inner)/(rho_media_2*vel_media_2) * np.exp(1j * w / vel_media_2 * (x_hat(x, w) - l_inner))

    # Función de velocidad completa
    v = lambda x: v_1(x[0]) + (x[0] >= l_inner) * (v_2(x[0]) - v_1(x[0]))

    p_ex = Function(Q, name="p_ex")
    p_ex.interpolate(p)

    v_ex = Function(V, name="v_ex")
    v_ex.interpolate(v)

    return [w, p_ex, v_ex]

# %%
def eval_point_fast(u, bb, x, mesh):
    pt = np.array([x, 0.0, 0.0], dtype=np.float64)

    # 1) Buscamos celas candidatas no árbol
    candidates = geometry.compute_collisions_points(bb, pt)

    # 2) Filtramos celas que realmente conteñen o punto
    cell = geometry.compute_colliding_cells(mesh, candidates, pt)

    if len(cell) == 0:
        return np.nan

    # 3) Avaliar a función FEM
    P = np.array([pt])
    C = np.array([cell.array[0]], dtype=np.int32)

    val = u.eval(P, C)
    return val[0]

# %%
def normalize_at_Lx(u, bb, Lx, mesh):
    val_Lx = eval_point_fast(u, bb, Lx, mesh)
    u.x.array[:] /= val_Lx   # normalizando respecto do valor en [Lx, 0, 0]
    return u

# %%
def get_closest_approx_eigenpair(exact_eigenvalue_idx, solver, Q, V, dof, sigma_i, mesh, verbose=False, plot=False):
    """
    Devuelve el autovalor y autovector más cercano a omega_target
    usando distancia compleja |λ - λ_target|, sin usar get_approx_eigenpair.

    Returns
    -------
    lambda_best : complex
    x_best : PETSc.Vec (copia del autovector)
    idx_best : int (índice raw en solver)
    p_h:    Function
    v_h: Function
    """
    p_exact = [None] * 5  # Almacena los autovectores exactos de presión
    v_exact = [None] * 5  # Almacena los autovectores exactos de velocidad
    p_approx = [None] * 5  # Almacena los autovectores exactos de presión
    v_approx = [None] * 5  # Almacena los autovectores exactos de velocidad
    best = None
    best_3 = None

    # Vector temporal para extraer Eigenpairs
    p_h = Function(Q, name="p_h")
    v_h = Function(V, name="v_h")

    # Número de modos convergidos
    nconv = solver.getConverged()
    if nconv == 0:
        raise RuntimeError("No hay autovalores convergidos")

    # Vector temporal para extraer Eigenpairs
    vrA, vi = solver.getOperators()[0].getVecs()

    match pml_profile:
        case 'piecewise':
            x_hat = lambda x, w: x + (x >= Lx) * (1j / w) * sigma_i * (x - Lx)

        case 'quadratic':
            x_hat=lambda x, w: x + (x >= Lx) * (1j / w) * sigma_i* (x - Lx) ** 3/ (3 * pml_thickness**2)

        case 'singular':
            x_hat=lambda x, w: x + (x >= Lx) * (1j / w) * sigma_i *(-np.log((Lx + pml_thickness - x)/pml_thickness))

    [exact_eigenvalue, p_exact, v_exact] =   get_exact_eigenpair(exact_eigenvalue_idx, Q, V, x_hat)

    bb = bb_tree(mesh, mesh.topology.dim)
    for k in range(nconv):
        approx_eigenvalue = solver.getEigenvalue(k) * 1j
        solver.getEigenpair(k, vrA)
        # Vector temporal para extraer Eigenpairs
        p_h = Function(Q, name="p_h")
        v_h = Function(V, name="v_h")
        [p_h, v_h]=assign_eigenvector_to_functions(vrA = vrA, p_h = p_h, v_h = v_h, dof = dof)

        # --- autovalores ---
        err_eig = abs(approx_eigenvalue - exact_eigenvalue) / abs(exact_eigenvalue)

        # --- autovectores ---

        p_h=normalize_at_Lx(p_h, bb, Lx, mesh)
        v_h=normalize_at_Lx(v_h, bb, Lx, mesh)
        p_exact=normalize_at_Lx(p_exact, bb, Lx, mesh)
        v_exact=normalize_at_Lx(v_exact, bb, Lx, mesh)


        # Errores L2 en dominio físico
        err_p = eigenvector_L2_error_physical(p_h, p_exact, Lx, mesh)
        err_v = eigenvector_L2_error_physical(v_h, v_exact, Lx, mesh)

        # Total
        err = (err_eig + err_p + err_v) / 3


        if best is None or err < best[2]:
            best = (approx_eigenvalue, k, err,err_eig, err_p, err_v)

    closest_eig, idx_best, rel_err_total, rel_err_eig_best, rel_err_p_best, rel_err_v_best = best

    # Vector temporal para extraer Eigenpairs
    p_h = Function(Q, name="p_h")
    v_h = Function(V, name="v_h")
    vrA, vi = solver.getOperators()[0].getVecs()
    solver.getEigenpair(idx_best, vrA)
    [p_approx, v_approx]=assign_eigenvector_to_functions(vrA = vrA, p_h = p_h, v_h = v_h, dof = dof)

    if verbose:
        print(f"$\sigma_i={sigma_i}$")
        print(f"$[Closest to \omega={exact_eigenvalue}] idx={idx_best}  \omega={closest_eig}  \epsilon_r={(rel_err_eig_best+rel_err_p_best+rel_err_v_best)/3} \epsilon_r(\omega)={rel_err_eig_best}  \epsilon_r(p)={rel_err_p_best} \epsilon_r(v)={rel_err_v_best}$")


    if plot:
        from dolfinx import geometry

        fig, axes = plt.subplots(1, 2, figsize=(12,8))

        # ============================================================
        #  FILA 1 — AUTOVECTORES p
        # ============================================================

        # --- p, modo 0 ---
        ax = axes[0]


        val_Lx = eval_point_fast(p_approx, bb, Lx, mesh)
        p_approx.x.array[:] /= val_Lx   # normalizando respecto do valor en [Lx, 0, 0]
        val_Lx = eval_point_fast(p_exact, bb, Lx, mesh)
        p_exact.x.array[:] /= val_Lx
        xx = np.linspace(0, Lx+pml_thickness, 2000)
        yy = [eval_point_fast(p_approx, bb, x, mesh) for x in xx]
        ax.plot(xx, np.real(yy), label="Re(p)", linestyle="-.")
        yy = [eval_point_fast(p_exact, bb, x, mesh) for x in xx]
        ax.plot(xx, np.real(yy), label="Re(p)", linestyle="-")
        ax.set_xlabel("x [m]")
        ax.set_ylabel("p(x) [Pa]")
        ax.set_title("Modo {} con sigma singular".format(0))
        ax.grid(True)


        ax = axes[1]
        val_Lx = eval_point_fast(v_approx, bb, Lx, mesh)
        v_approx.x.array[:] /= val_Lx   # normalizando respecto do valor en [Lx, 0, 0]
        val_Lx = eval_point_fast(v_exact, bb, Lx, mesh)
        v_exact.x.array[:] /= val_Lx
        xx = np.linspace(0, Lx+pml_thickness, 2000)
        yy = [eval_point_fast(v_approx, bb, x, mesh) for x in xx]
        ax.plot(xx, np.real(yy), label="Re(v)", linestyle="-.")
        yy = [eval_point_fast(v_exact, bb, x, mesh) for x in xx]
        ax.plot(xx, np.real(yy), label="Re(v)", linestyle="-")
        ax.set_xlabel("x [m]")
        ax.set_ylabel("v(x) ")
        ax.grid(True)

        plt.show()

    return exact_eigenvalue, p_exact, v_exact, closest_eig, p_approx, v_approx, rel_err_eig_best, rel_err_p_best, rel_err_v_best, (rel_err_eig_best + rel_err_p_best + rel_err_v_best) / 3

# %%
# Diccionarios onde gardar os erros para cada refinamento N
rel_err_eig_sigma_sweep = {0: {}, 3: {}}   # erros para modo 0 e 3
rel_err_p_sigma_sweep = {0: {}, 3: {}}   # erros para modo 0 e 3
rel_err_v_sigma_sweep = {0: {}, 3: {}}   # erros para modo 0 e 3
rel_err_total_sigma_sweep = {0: {}, 3: {}}   # erros para modo 0 e 3

approx_omega  = {0: {}, 3: {}}
approx_p      = {0: {}, 3: {}}
approx_v      = {0: {}, 3: {}}
exact_p      = {0: {}, 3: {}}
exact_v      = {0: {}, 3: {}}
exact_omega  = {0: {}, 3: {}}

# Iterar sobre N = 0,1,2 → corresponde a h_i[0], h_i[1], h_i[2]
for N_i, h_i in zip(N, h):

    print(f"\n=== Executando para N = {N_i}, h = {h_i} ===")

    # Inicializar listas baleiras para este N
    rel_err_eig_sigma_sweep[0][N_i] = []
    rel_err_eig_sigma_sweep[3][N_i] = []
    rel_err_p_sigma_sweep[0][N_i] = []
    rel_err_p_sigma_sweep[3][N_i] = []
    rel_err_v_sigma_sweep[0][N_i] = []
    rel_err_v_sigma_sweep[3][N_i] = []
    rel_err_total_sigma_sweep[0][N_i] = []
    rel_err_total_sigma_sweep[3][N_i] = []
    

    approx_omega[0][N_i] = []
    approx_omega[3][N_i] = []

    approx_p[0][N_i] = []
    approx_p[3][N_i] = []
    approx_v[0][N_i] = []
    approx_v[3][N_i] = []

    exact_p[0][N_i] = []
    exact_p[3][N_i] = []

    exact_v[0][N_i] = []
    exact_v[3][N_i] = []

    exact_omega[0][N_i] = []
    exact_omega[3][N_i] = []

    # Crear nova malla para este refinamento
    mesh = create_interval(
        MPI.COMM_WORLD,
        int((Lx + pml_thickness) / h_i),
        [0, Lx + pml_thickness]
    )

    # Percorrer sigma_sweep_piecewise
    for i, sigma_i in enumerate(sigma_sweep):
        match pml_profile:
            case 'piecewise':
                print(f"Computing for sigma_i = {sigma_i:.2f} (piecewise)")
                sigma_function = lambda x: sigma_i
            case 'quadratic':
                print(f"Computing for sigma_i = {sigma_i:.2f} (quadratic)")
                sigma_function = lambda x: sigma_i * (x[0] - Lx)**2 / (pml_thickness**2)
            case 'singular':
                print(f"Computing for sigma_i = {sigma_i:.2f} (singular)")
                sigma_function = lambda x: sigma_i/(Lx+pml_thickness-x[0])

        sigma_piecewise_ufl = lambda x: sigma_i
        solver_target_0, mesh, Q_, V_, dof_ = get_configured_problem(mesh, degree, sigma_function, target[0])
        solver_target_3, mesh, Q_, V_, dof_ = get_configured_problem(mesh, degree, sigma_function, target[1])
        (eig_ex0, p_ex0, v_ex0, eig0, p0, v0, err0_eig, err0_p, err0_v, total_error) = get_closest_approx_eigenpair(1, solver_target_0, Q_, V_, dof_, sigma_i, mesh,verbose=True, plot=False)
        (eig_ex3, p_ex3, v_ex3, eig3, p3, v3, err3_eig, err3_p, err3_v, total_error) = get_closest_approx_eigenpair(4, solver_target_3, Q_, V_, dof_, sigma_i, mesh,verbose=True, plot=False)

        err0 = (err0_eig + err0_p + err0_v ) /3
        err3 = (err3_eig + err3_p + err3_v) / 3
        # Gardar resultados
        approx_omega[0][N_i].append(eig0)
        approx_omega[3][N_i].append(eig3)

        exact_omega[0][N_i].append(eig_ex0)
        exact_omega[3][N_i].append(eig_ex3)
        approx_p[0][N_i].append(p0)
        approx_p[3][N_i].append(p3)

        approx_v[0][N_i].append(v0)
        approx_v[3][N_i].append(v3)

        exact_p[0][N_i].append(p_ex0)
        exact_p[3][N_i].append(p_ex3)

        exact_v[0][N_i].append(v_ex0)
        exact_v[3][N_i].append(v_ex3)


        rel_err_eig_sigma_sweep[0][N_i].append(err0_eig)
        rel_err_eig_sigma_sweep[3][N_i].append(err3_eig)

        rel_err_p_sigma_sweep[0][N_i].append(err0_p)
        rel_err_p_sigma_sweep[3][N_i].append(err3_p)

        rel_err_v_sigma_sweep[0][N_i].append(err0_v)
        rel_err_v_sigma_sweep[3][N_i].append(err3_v)

        rel_err_total_sigma_sweep[0][N_i].append(err0)
        rel_err_total_sigma_sweep[3][N_i].append(err3)
# Out:
# === Executando para N = 1, h = 0.0625 ===
# Computing for sigma_i = 1.00 (piecewise)
# $\sigma_i=1$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=2  \omega=(15.377060721036484-0.25708293249348163j)  \epsilon_r=(1.3923579065101803+0j) \epsilon_r(\omega)=0.26771766904494626  \epsilon_r(p)=(2.081846952499933+0j) \epsilon_r(v)=(1.8275090979856616+0j)$
# $\sigma_i=1$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=7  \omega=(63.95901379656589-0.22368051254098942j)  \epsilon_r=(1.2617834715016225+0j) \epsilon_r(\omega)=0.2749763211389986  \epsilon_r(p)=(1.749501973560145+0j) \epsilon_r(v)=(1.7608721198057247+0j)$
# Computing for sigma_i = 2.00 (piecewise)
# $\sigma_i=2$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=2  \omega=(15.369376168118034-0.5145849915567232j)  \epsilon_r=(1.2747396004070688+0j) \epsilon_r(\omega)=0.2562721835385567  \epsilon_r(p)=(1.922712122020731+0j) \epsilon_r(v)=(1.6452344956619191+0j)$
# $\sigma_i=2$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=7  \omega=(63.9578898383445-0.4492735424704327j)  \epsilon_r=(1.2405582496992973+0j) \epsilon_r(\omega)=0.2743504550268332  \epsilon_r(p)=(1.7063647474443953+0j) \epsilon_r(v)=(1.740959546626664+0j)$
# Computing for sigma_i = 3.00 (piecewise)
# $\sigma_i=3$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=2  \omega=(15.356494067725894-0.7729447695803104j)  \epsilon_r=(1.1384503804159483+0j) \epsilon_r(\omega)=0.2455612267560565  \epsilon_r(p)=(1.723829587302596+0j) \epsilon_r(v)=(1.4459603271891925+0j)$
# $\sigma_i=3$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(48.90866914862931-1.2812126418031802j)  \epsilon_r=(1.0277438209765513+0j) \epsilon_r(\omega)=0.03253753563828645  \epsilon_r(p)=(1.7559407959709155+0j) \epsilon_r(v)=(1.2947531313204526+0j)$
# Computing for sigma_i = 4.00 (piecewise)
# $\sigma_i=4$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.567576873232229-0.7865224636538276j)  \epsilon_r=(0.8372787140431726+0j) \epsilon_r(\omega)=0.1105824896855867  \epsilon_r(p)=(1.7736952314878842+0j) \epsilon_r(v)=(0.627558420956047+0j)$
# $\sigma_i=4$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(48.89255333666679-1.9219236707217937j)  \epsilon_r=(0.7952388820449254+0j) \epsilon_r(\omega)=0.027830689118915137  \epsilon_r(p)=(1.2490869013138701+0j) \epsilon_r(v)=(1.1087990557019909+0j)$
# Computing for sigma_i = 5.00 (piecewise)
# $\sigma_i=5$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.567080137046768-0.9735734119448473j)  \epsilon_r=(0.6253161020729603+0j) \epsilon_r(\omega)=0.09591987163173692  \epsilon_r(p)=(1.259380199854539+0j) \epsilon_r(v)=(0.520648234732605+0j)$
# $\sigma_i=5$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(48.76370336868919-2.613083613634568j)  \epsilon_r=(0.6808452745192275+0j) \epsilon_r(\omega)=0.030971691773196565  \epsilon_r(p)=(0.9943134916756213+0j) \epsilon_r(v)=(1.0172506401088648+0j)$
# Computing for sigma_i = 6.00 (piecewise)
# $\sigma_i=6$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.566431907121988-1.153735714612143j)  \epsilon_r=(0.4740104923297422+0j) \epsilon_r(\omega)=0.08179725067003742  \epsilon_r(p)=(0.9166839195575509+0j) \epsilon_r(v)=(0.4235503067616383+0j)$
# $\sigma_i=6$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(48.57067167252723-3.3469424708737368j)  \epsilon_r=(0.6323989306614666+0j) \epsilon_r(\omega)=0.040704459536336925  \epsilon_r(p)=(0.8803277295370918+0j) \epsilon_r(v)=(0.976164602910971+0j)$
# Computing for sigma_i = 7.00 (piecewise)
# $\sigma_i=7$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.565615296173705-1.3251426485973063j)  \epsilon_r=(0.3598475085951667+0j) \epsilon_r(\omega)=0.06836098909189554  \epsilon_r(p)=(0.6735706165547273+0j) \epsilon_r(v)=(0.3376109201388773+0j)$
# $\sigma_i=7$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(48.35478158883029-4.140505590106104j)  \epsilon_r=(0.6128997130442372+0j) \epsilon_r(\omega)=0.0541658808123579  \epsilon_r(p)=(0.8289695382506407+0j) \epsilon_r(v)=(0.9555637200697132+0j)$
# Computing for sigma_i = 8.00 (piecewise)
# $\sigma_i=8$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.56462786817129-1.4857038206063296j)  \epsilon_r=(0.2710732398912745+0j) \epsilon_r(\omega)=0.05577502381820629  \epsilon_r(p)=(0.494235797370882+0j) \epsilon_r(v)=(0.2632088984847354+0j)$
# $\sigma_i=8$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(48.152410365937655-4.991179776179308j)  \epsilon_r=(0.606205892400615+0j) \epsilon_r(\omega)=0.06962419522253344  \epsilon_r(p)=(0.8064107774325391+0j) \epsilon_r(v)=(0.9425827045467724+0j)$
# Computing for sigma_i = 9.00 (piecewise)
# $\sigma_i=9$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.563503797197773-1.6331510496928046j)  \epsilon_r=(0.20109756260569991+0j) \epsilon_r(\omega)=0.04421729948562538  \epsilon_r(p)=(0.35893292250145625+0j) \epsilon_r(v)=(0.20014246583001816+0j)$
# $\sigma_i=9$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(47.98080484512609-5.878156509531769j)  \epsilon_r=(0.6059671047279435+0j) \epsilon_r(\omega)=0.08610657673246057  \epsilon_r(p)=(0.7987606310103681+0j) \epsilon_r(v)=(0.9330341064410019+0j)$
# Computing for sigma_i = 10.00 (piecewise)
# $\sigma_i=10$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.562347082995016-1.765180618611579j)  \epsilon_r=(0.1458852362203651+0j) \epsilon_r(\omega)=0.03386863208912009  \epsilon_r(p)=(0.2558803277845986+0j) \epsilon_r(v)=(0.1479067487873765+0j)$
# $\sigma_i=10$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(47.838404855380574-6.783388052426771j)  \epsilon_r=(0.6094380840529195+0j) \epsilon_r(\omega)=0.10312932973185204  \epsilon_r(p)=(0.7992682050329519+0j) \epsilon_r(v)=(0.9259167173939548+0j)$
# Computing for sigma_i = 11.00 (piecewise)
# $\sigma_i=11$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.561367646170181-1.879735152875603j)  \epsilon_r=(0.10275877066303177+0j) \epsilon_r(\omega)=0.024890525444747374  \epsilon_r(p)=(0.17753638927267054+0j) \epsilon_r(v)=(0.10584939727167741+0j)$
# $\sigma_i=11$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(47.718319531855116-7.698079594544951j)  \epsilon_r=(0.6151277422883333+0j) \epsilon_r(\omega)=0.12048394939470287  \epsilon_r(p)=(0.8041179265347461+0j) \epsilon_r(v)=(0.920781350935551+0j)$
# Computing for sigma_i = 12.00 (piecewise)
# $\sigma_i=12$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.56089599223123-1.9754268791778544j)  \epsilon_r=(0.06976720738684672+0j) \epsilon_r(\omega)=0.017391625645905552  \epsilon_r(p)=(0.11867724642136174+0j) \epsilon_r(v)=(0.07323275009327287+0j)$
# $\sigma_i=12$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(47.6148167117442-8.618728171018265j)  \epsilon_r=(0.6221325903161976+0j) \epsilon_r(\omega)=0.1380756502179391  \epsilon_r(p)=(0.811117755587062+0j) \epsilon_r(v)=(0.9172043651435918+0j)$
# Computing for sigma_i = 13.00 (piecewise)
# $\sigma_i=13$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.561342755366645-2.0519952627074285j)  \epsilon_r=(0.045324293363431994+0j) \epsilon_r(\omega)=0.01139108997896517  \epsilon_r(p)=(0.07532208422963703+0j) \epsilon_r(v)=(0.04925970588169378+0j)$
# $\sigma_i=13$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(47.524018460925596-9.54384215723717j)  \epsilon_r=(0.6298951099933344+0j) \epsilon_r(\omega)=0.15585196041273497  \epsilon_r(p)=(0.8190295984913691+0j) \epsilon_r(v)=(0.9148037710758994+0j)$
# Computing for sigma_i = 14.00 (piecewise)
# $\sigma_i=14$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.563095262394055-2.1105653592715665j)  \epsilon_r=(0.028021579143629453+0j) \epsilon_r(\omega)=0.006797913461416371  \epsilon_r(p)=(0.04415010039558301+0j) \epsilon_r(v)=(0.033116723573888986+0j)$
# $\sigma_i=14$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(47.44332183565968-10.472601710910112j)  \epsilon_r=(0.6380713080336904+0j) \epsilon_r(\omega)=0.17377780340823099  \epsilon_r(p)=(0.8271656359498283+0j) \epsilon_r(v)=(0.9132704847430121+0j)$
# Computing for sigma_i = 15.00 (piecewise)
# $\sigma_i=15$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.566403576854238-2.153486721910846j)  \epsilon_r=(0.01654219899640535+0j) \epsilon_r(\omega)=0.0034285342772918384  \epsilon_r(p)=(0.0222836673681524+0j) \epsilon_r(v)=(0.023914395343771818+0j)$
# $\sigma_i=15$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(47.3708963183964-11.404421479329908j)  \epsilon_r=(0.6464494796229092+0j) \epsilon_r(\omega)=0.19182695098213087  \epsilon_r(p)=(0.8351529426932742+0j) \epsilon_r(v)=(0.9123685451933228+0j)$
# Computing for sigma_i = 16.00 (piecewise)
# $\sigma_i=16$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.571333783563997-2.183775617760115j)  \epsilon_r=(0.009606421895630955+0j) \epsilon_r(\omega)=0.0011237372869685616  \epsilon_r(p)=(0.0075485311743420675+0j) \epsilon_r(v)=(0.020146997225582237+0j)$
# $\sigma_i=16$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(47.30538669638476-12.3388206829412j)  \epsilon_r=(0.6549000588140643+0j) \epsilon_r(\omega)=0.20997869248677464  \epsilon_r(p)=(0.842798867490803+0j) \epsilon_r(v)=(0.9119226164646154+0j)$
# Computing for sigma_i = 17.00 (piecewise)
# $\sigma_i=17$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.577807507239173-2.2044508239043346j)  \epsilon_r=(0.008621529677693883+0j) \epsilon_r(\omega)=0.0010604776924543122  \epsilon_r(p)=(0.005368004535889654+0j) \epsilon_r(v)=(0.019436106804737684+0j)$
# $\sigma_i=17$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(47.245748553329804-13.27538455856062j)  \epsilon_r=(0.6633446439596205+0j) \epsilon_r(\omega)=0.22821621630887423  \epsilon_r(p)=(0.850013862233+0j) \epsilon_r(v)=(0.911803853336987+0j)$
# Computing for sigma_i = 18.00 (piecewise)
# $\sigma_i=18$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.585675550599028-2.218064392488175j)  \epsilon_r=(0.011451635007755485+0j) \epsilon_r(\omega)=0.002226803312645265  \epsilon_r(p)=(0.012342805716837761+0j) \epsilon_r(v)=(0.01978529599378343+0j)$
# $\sigma_i=18$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(47.19115450384339-14.21375024008196j)  \epsilon_r=(0.6717367860534657+0j) \epsilon_r(\omega)=0.24652563554691503  \epsilon_r(p)=(0.8567668507984604+0j) \epsilon_r(v)=(0.9119178718150215+0j)$
# Computing for sigma_i = 19.00 (piecewise)
# $\sigma_i=19$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.59477104580131-2.226524494008083j)  \epsilon_r=(0.013887800617090676+0j) \epsilon_r(\omega)=0.0031986526877564253  \epsilon_r(p)=(0.018163979842096806+0j) \epsilon_r(v)=(0.020300769321418794+0j)$
# $\sigma_i=19$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(47.14093703405466-15.153598565362415j)  \epsilon_r=(0.6800500078877764+0j) \epsilon_r(\omega)=0.2648953176904422  \epsilon_r(p)=(0.8630592257332323+0j) \epsilon_r(v)=(0.9121954802396546+0j)$
# Computing for sigma_i = 20.00 (piecewise)
# $\sigma_i=20$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.604927953153249-2.2311323469436375j)  \epsilon_r=(0.01597057701617432+0j) \epsilon_r(\omega)=0.004024917368218064  \epsilon_r(p)=(0.02311158770385471+0j) \epsilon_r(v)=(0.02077522597645019+0j)$
# $\sigma_i=20$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(47.09455096965944-16.094647409286665j)  \epsilon_r=(0.6882702938974592+0j) \epsilon_r(\omega)=0.2833153935769575  \epsilon_r(p)=(0.8689096547786547+0j) \epsilon_r(v)=(0.9125858333367656+0j)$
# Computing for sigma_i = 21.00 (piecewise)
# $\sigma_i=21$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.615977863937898-2.2327144467351183j)  \epsilon_r=(0.017904569328715605+0j) \epsilon_r(\omega)=0.00478130327523811  \epsilon_r(p)=(0.02766612355568622+0j) \epsilon_r(v)=(0.021266281155222486+0j)$
# $\sigma_i=21$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(47.05154722642002-17.03664576950313j)  \epsilon_r=(0.6963913617287611+0j) \epsilon_r(\omega)=0.3017773875054721  \epsilon_r(p)=(0.8743452312797813+0j) \epsilon_r(v)=(0.9130514664010304+0j)$
# Computing for sigma_i = 22.00 (piecewise)
# $\sigma_i=22$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.627741043217425-2.231768672199649j)  \epsilon_r=(0.019862231092088296+0j) \epsilon_r(\omega)=0.005520459974361117  \epsilon_r(p)=(0.03215767658448877+0j) \epsilon_r(v)=(0.021908556717414998+0j)$
# $\sigma_i=22$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(47.01155358746441-17.979368557677116j)  \epsilon_r=(0.7044116748350874+0j) \epsilon_r(\omega)=0.3202739341896764  \epsilon_r(p)=(0.8793963751654394+0j) \epsilon_r(v)=(0.9135647151501463+0j)$
# Computing for sigma_i = 23.00 (piecewise)
# $\sigma_i=23$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.640021011009203-2.22858792464307j)  \epsilon_r=(0.021968988668623346+0j) \epsilon_r(\omega)=0.006274996833911973  \epsilon_r(p)=(0.036791430474907134+0j) \epsilon_r(v)=(0.022840538697050924+0j)$
# $\sigma_i=23$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(46.97426018559222-18.922612095582625j)  \epsilon_r=(0.712332550527589+0j) \epsilon_r(\omega)=0.33879855929606056  \epsilon_r(p)=(0.8840939585937959+0j) \epsilon_r(v)=(0.9141051336929109+0j)$
# Computing for sigma_i = 24.00 (piecewise)
# $\sigma_i=24$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.652605764911405-2.2233521388560438j)  \epsilon_r=(0.02430723182607631+0j) \epsilon_r(\omega)=0.007063276180916955  \epsilon_r(p)=(0.04168621677289895+0j) \epsilon_r(v)=(0.024172202524413024+0j)$
# $\sigma_i=24$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(46.939408317545414-19.866190261847372j)  \epsilon_r=(0.720156960580923+0j) \epsilon_r(\omega)=0.3573455069466305  \epsilon_r(p)=(0.8884677498060186+0j) \epsilon_r(v)=(0.9146576249901203+0j)$
# Computing for sigma_i = 25.00 (piecewise)
# $\sigma_i=25$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.665275102571604-2.216190861844582j)  \epsilon_r=(0.02692310607946716+0j) \epsilon_r(\omega)=0.007894212057397721  \epsilon_r(p)=(0.04690482314709223+0j) \epsilon_r(v)=(0.02597028303391153+0j)$
# $\sigma_i=25$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(46.906781713965685-20.809931200588288j)  \epsilon_r=(0.7278887715480409+0j) \epsilon_r(\omega)=0.3759096021184055  \epsilon_r(p)=(0.8925456333785896+0j) \epsilon_r(v)=(0.9152110791471276+0j)$
# Computing for sigma_i = 26.00 (piecewise)
# $\sigma_i=26$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.677811741270647-2.2072218223929707j)  \epsilon_r=(0.029834282105585946+0j) \epsilon_r(\omega)=0.008770753713182037  \epsilon_r(p)=(0.05247522691045203+0j) \epsilon_r(v)=(0.02825686569312377+0j)$
# $\sigma_i=26$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(46.87619967080281-21.75367449449383j)  \epsilon_r=(0.7355322652739302+0j) \epsilon_r(\omega)=0.3944861391271623  \epsilon_r(p)=(0.8963532820243746+0j) \epsilon_r(v)=(0.9157573746702542+0j)$
# Computing for sigma_i = 27.00 (piecewise)
# $\sigma_i=27$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.690013373249242-2.196571211455323j)  \epsilon_r=(0.03303840839274656+0j) \epsilon_r(\omega)=0.009692272999979937  \epsilon_r(p)=(0.05840466785243243+0j) \epsilon_r(v)=(0.03101828432582733+0j)$
# $\sigma_i=27$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(46.84751162165021-22.697268710742573j)  \epsilon_r=(0.7430918384692392+0j) \epsilon_r(\omega)=0.4130707897189003  \epsilon_r(p)=(0.8999140851698888+0j) \epsilon_r(v)=(0.9162906405189286+0j)$
# Computing for sigma_i = 28.00 (piecewise)
# $\sigma_i=28$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.701703097116242-2.1843809671855534j)  \epsilon_r=(0.03652109069001205+0j) \epsilon_r(\omega)=0.010656141575431585  \epsilon_r(p)=(0.06468863664098908+0j) \epsilon_r(v)=(0.034218493853615486+0j)$
# $\sigma_i=28$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=7  \omega=(66.16619825801281-14.548138584815502j)  \epsilon_r=(0.7446416267022139+0j) \epsilon_r(\omega)=0.4001710100102468  \epsilon_r(p)=(0.9264919259009431+0j) \epsilon_r(v)=(0.9072619441954518+0j)$
# Computing for sigma_i = 29.00 (piecewise)
# $\sigma_i=29$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.71273654032306-2.1708077528249556j)  \epsilon_r=(0.040262171141693476+0j) \epsilon_r(\omega)=0.011658740215261636  \epsilon_r(p)=(0.0713164463388569+0j) \epsilon_r(v)=(0.03781132687096189+0j)$
# $\sigma_i=29$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=7  \omega=(65.9627297781592-14.920015684718082j)  \epsilon_r=(0.7436167756447802+0j) \epsilon_r(\omega)=0.401597448104305  \epsilon_r(p)=(0.9246848663298293+0j) \epsilon_r(v)=(0.9045680125002064+0j)$
# Computing for sigma_i = 30.00 (piecewise)
# $\sigma_i=30$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.723005069162538-2.1560175254946596j)  \epsilon_r=(0.04423987712456762+0j) \epsilon_r(\omega)=0.012696080919910122  \epsilon_r(p)=(0.07827457871915164+0j) \epsilon_r(v)=(0.04174897173464109+0j)$
# $\sigma_i=30$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=7  \omega=(65.70257310850171-15.310038498170739j)  \epsilon_r=(0.7423189870071681+0j) \epsilon_r(\omega)=0.4025684491375995  \epsilon_r(p)=(0.9226458270634275+0j) \epsilon_r(v)=(0.9017426848204779+0j)$
# Computing for sigma_i = 31.00 (piecewise)
# $\sigma_i=31$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.732435413789435-2.1401786200477093j)  \epsilon_r=(0.048433144174904796+0j) \epsilon_r(\omega)=0.0137641703192679  \epsilon_r(p)=(0.08554861078438845+0j) \epsilon_r(v)=(0.04598665142105804+0j)$
# $\sigma_i=31$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=7  \omega=(65.39610299112167-15.719060462580513j)  \epsilon_r=(0.7409002889922732+0j) \epsilon_r(\omega)=0.4033165010325487  \epsilon_r(p)=(0.9204751467018526+0j) \epsilon_r(v)=(0.8989092192424186+0j)$
# Computing for sigma_i = 32.00 (piecewise)
# $\sigma_i=32$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.740986602746366-2.1234552428414384j)  \epsilon_r=(0.052822685973307276+0j) \epsilon_r(\omega)=0.01485920452113435  \epsilon_r(p)=(0.09312425348210121+0j) \epsilon_r(v)=(0.05048459991668628+0j)$
# $\sigma_i=32$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=7  \omega=(65.04990841138287-16.145333321297905j)  \epsilon_r=(0.7394637809605676+0j) \epsilon_r(\omega)=0.4039786896151545  \epsilon_r(p)=(0.918247915735483+0j) \epsilon_r(v)=(0.8961647375310655+0j)$
# Computing for sigma_i = 33.00 (piecewise)
# $\sigma_i=33$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.748645278632992-2.106002358163149j)  \epsilon_r=(0.05739132674784991+0j) \epsilon_r(\omega)=0.015977658181575514  \epsilon_r(p)=(0.10098785093602791+0j) \epsilon_r(v)=(0.05520847112594631+0j)$
# $\sigma_i=33$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=7  \omega=(64.66769133257606-16.586437483787844j)  \epsilon_r=(0.7380775705817949+0j) \epsilon_r(\omega)=0.4046353112361789  \epsilon_r(p)=(0.9160176938589841+0j) \epsilon_r(v)=(0.8935797066502218+0j)$
# Computing for sigma_i = 34.00 (piecewise)
# $\sigma_i=34$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.755420358892835-2.087962272044612j)  \epsilon_r=(0.06212395243960279+0j) \epsilon_r(\omega)=0.01711631077352877  \epsilon_r(p)=(0.1091265660080442+0j) \epsilon_r(v)=(0.06012898053723539+0j)$
# $\sigma_i=34$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=7  \omega=(64.25116105769791-17.04003644057777j)  \epsilon_r=(0.7367873503188644+0j) \epsilon_r(\omega)=0.40533527383484336  \epsilon_r(p)=(0.913822750372656+0j) \epsilon_r(v)=(0.8912040267490942+0j)$
# Computing for sigma_i = 35.00 (piecewise)
# $\sigma_i=35$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.761337757412406-2.069462800728674j)  \epsilon_r=(0.06700729411039019+0j) \epsilon_r(\omega)=0.018272238540239464  \epsilon_r(p)=(0.11752839568065658+0j) \epsilon_r(v)=(0.06522124811027451+0j)$
# $\sigma_i=35$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=6  \omega=(63.80064056368999-17.50410758393837j)  \epsilon_r=(0.7356250900100242+0j) \epsilon_r(\omega)=0.4061107363083598  \epsilon_r(p)=(0.911691233159102+0j) \epsilon_r(v)=(0.8890733005626108+0j)$
# Computing for sigma_i = 36.00 (piecewise)
# $\sigma_i=36$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.76643561096971-2.0506167121407928j)  \epsilon_r=(0.07202965953080025+0j) \epsilon_r(\omega)=0.019442790148884583  \epsilon_r(p)=(0.12618210440909478+0j) \epsilon_r(v)=(0.07046408403442139+0j)$
# $\sigma_i=36$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=6  \omega=(63.31542206981484-17.9769723610149j)  \epsilon_r=(0.7346146691580018+0j) \epsilon_r(\omega)=0.40698533359813777  \epsilon_r(p)=(0.9096448672836219+0j) \epsilon_r(v)=(0.8872138065922457+0j)$
# Computing for sigma_i = 37.00 (piecewise)
# $\sigma_i=37$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.770760226500425-2.0315220787061863j)  \epsilon_r=(0.07718067031376603+0j) \epsilon_r(\omega)=0.020625556749501377  \epsilon_r(p)=(0.13507712696354823+0j) \epsilon_r(v)=(0.07583932722824852+0j)$
# $\sigma_i=37$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=6  \omega=(62.79394727071335-18.457259674299756j)  \epsilon_r=(0.7337755505074375+0j) \epsilon_r(\omega)=0.40797892048530504  \epsilon_r(p)=(0.9077015267089923+0j) \epsilon_r(v)=(0.8856462043280153+0j)$
# Computing for sigma_i = 38.00 (piecewise)
# $\sigma_i=38$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.77436280387191-2.0122632125837576j)  \epsilon_r=(0.08245102935200772+0j) \epsilon_r(\omega)=0.021818342281553813  \epsilon_r(p)=(0.14420346876373752+0j) \epsilon_r(v)=(0.08133127701073183+0j)$
# $\sigma_i=38$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=5  \omega=(62.233865253215676-18.943853431897008j)  \epsilon_r=(0.7331252983281572+0j) \epsilon_r(\omega)=0.40911050636096824  \epsilon_r(p)=(0.905877067851137+0j) \epsilon_r(v)=(0.8843883207723663+0j)$
# Computing for sigma_i = 39.00 (piecewise)
# $\sigma_i=39$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.777296890920098-1.992911921449394j)  \epsilon_r=(0.08783232622421407+0j) \epsilon_r(\omega)=0.023019136814383206  \epsilon_r(p)=(0.15355161723072988+0j) \epsilon_r(v)=(0.08692622462752915+0j)$
# $\sigma_i=39$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=5  \omega=(61.6319950180485-19.43584184686184j)  \epsilon_r=(0.7326814707451794+0j) \epsilon_r(\omega)=0.410400314383063  \epsilon_r(p)=(0.9041867274674619+0j) \epsilon_r(v)=(0.8834573703850136+0j)$
# Computing for sigma_i = 40.00 (piecewise)
# $\sigma_i=40$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.779616478246549-1.973528895201464j)  \epsilon_r=(0.09331687989109051+0j) \epsilon_r(\omega)=0.024226093909962162  \epsilon_r(p)=(0.1631124692370408+0j) \epsilon_r(v)=(0.09261207652626856+0j)$
# $\sigma_i=40$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=4  \omega=(60.98419787918064-19.932473274261415j)  \epsilon_r=(0.7324632493060343+0j) \epsilon_r(\omega)=0.411871522059026  \epsilon_r(p)=(0.9026463120296758+0j) \epsilon_r(v)=(0.8828719138294013+0j)$
# Computing for sigma_i = 41.00 (piecewise)
# $\sigma_i=41$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.781374624445904-1.9541650971284037j)  \epsilon_r=(0.09889761439877699+0j) \epsilon_r(\omega)=0.02543751202384529  \epsilon_r(p)=(0.1728772751530501+0j) \epsilon_r(v)=(0.09837805601943561+0j)$
# $\sigma_i=41$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=4  \omega=(60.285144630660014-20.433118593269135j)  \epsilon_r=(0.7324930970524757+0j) \epsilon_r(\omega)=0.4135520808489404  \epsilon_r(p)=(0.9012733687130665+0j) \epsilon_r(v)=(0.8826538415954203+0j)$
# Computing for sigma_i = 42.00 (piecewise)
# $\sigma_i=42$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.782622504610224-1.9348630823259896j)  \epsilon_r=(0.10456796216698741+0j) \epsilon_r(\omega)=0.02665181949763046  \epsilon_r(p)=(0.18283759776287828+0j) \epsilon_r(v)=(0.1042144692404535+0j)$
# $\sigma_i=42$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=4  \omega=(59.52793683073825-20.937238339007077j)  \epsilon_r=(0.7327987474771458+0j) \epsilon_r(\omega)=0.4154769992838207  \epsilon_r(p)=(0.9000885359593457+0j) \epsilon_r(v)=(0.8828307071882713+0j)$
# Computing for sigma_i = 43.00 (piecewise)
# $\sigma_i=43$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.783408786650547-1.9156582016277262j)  \epsilon_r=(0.11032178950245264+0j) \epsilon_r(\omega)=0.027867562528912516  \epsilon_r(p)=(0.19298528346155597+0j) \epsilon_r(v)=(0.11011252251688945+0j)$
# $\sigma_i=43$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=4  \omega=(58.70350008804317-21.44435186453667j)  \epsilon_r=(0.7334159382651271+0j) \epsilon_r(\omega)=0.41769160519857806  \epsilon_r(p)=(0.8991173398901974+0j) \epsilon_r(v)=(0.883438869706606+0j)$
# Computing for sigma_i = 44.00 (piecewise)
# $\sigma_i=44$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.78377925521347-1.896579673263769j)  \epsilon_r=(0.11615333956656085+0j) \epsilon_r(\omega)=0.029083395495421372  \epsilon_r(p)=(0.2033124430218331+0j) \epsilon_r(v)=(0.11606418018242808+0j)$
# $\sigma_i=44$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=4  \omega=(57.799587597669415-21.954004691432008j)  \epsilon_r=(0.7343925890400241+0j) \epsilon_r(\omega)=0.4202566608066615  \epsilon_r(p)=(0.8983928788186546+0j) \epsilon_r(v)=(0.8845282274947565+0j)$
# Computing for sigma_i = 45.00 (piecewise)
# $\sigma_i=45$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.783776618375768-1.8776515196495154j)  \epsilon_r=(0.1220571887862105+0j) \epsilon_r(\omega)=0.030298073075863186  \epsilon_r(p)=(0.21381143945618133+0j) \epsilon_r(v)=(0.122062053826587+0j)$
# $\sigma_i=45$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=3  \omega=(56.79906002887908-22.465727827745436j)  \epsilon_r=(0.7357957895368124+0j) \epsilon_r(\omega)=0.42325704932566266  \epsilon_r(p)=(0.8979602509789097+0j) \epsilon_r(v)=(0.8861700683058649+0j)$
# Computing for sigma_i = 46.00 (piecewise)
# $\sigma_i=46$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.78344044621004-1.858893375647034j)  \epsilon_r=(0.12802821345519355+0j) \epsilon_r(\omega)=0.03151044370355634  \epsilon_r(p)=(0.22447488088144327+0j) \epsilon_r(v)=(0.12809931578058104+0j)$
# $\sigma_i=46$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=3  \omega=(55.67669102570752-22.97897696703438j)  \epsilon_r=(0.7377246163849672+0j) \epsilon_r(\omega)=0.4268178479220134  \epsilon_r(p)=(0.8978846026963301+0j) \epsilon_r(v)=(0.8884713985365585+0j)$
# Computing for sigma_i = 47.00 (piecewise)
# $\sigma_i=47$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.782807202091703-1.8403211793598038j)  \epsilon_r=(0.13406156395353774+0j) \epsilon_r(\omega)=0.03271944398529795  \epsilon_r(p)=(0.2352956167043123+0j) \epsilon_r(v)=(0.13416963117100297+0j)$
# $\sigma_i=47$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=2  \omega=(54.3925894695938-23.493023240203872j)  \epsilon_r=(0.7403364127291217+0j) \epsilon_r(\omega)=0.43113746699185207  \epsilon_r(p)=(0.8982675259965566+0j) \epsilon_r(v)=(0.8916042451989563+0j)$
# Computing for sigma_i = 48.00 (piecewise)
# $\sigma_i=48$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.781910337188728-1.8219477585152581j)  \epsilon_r=(0.140152644588048+0j) \epsilon_r(\omega)=0.03392409380508114  \epsilon_r(p)=(0.24626673582794556+0j) \epsilon_r(v)=(0.14026710413111723+0j)$
# $\sigma_i=48$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(52.87644076189293-24.0067129051977j)  \epsilon_r=(0.743909681303804+0j) \epsilon_r(\omega)=0.43656727349214924  \epsilon_r(p)=(0.8992860998060942+0j) \epsilon_r(v)=(0.8958756706131685+0j)$
# Computing for sigma_i = 49.00 (piecewise)
# $\sigma_i=49$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.780780426137472-1.8037833258164513j)  \epsilon_r=(0.1462970975278286+0j) \epsilon_r(\omega)=0.03512349190573466  \epsilon_r(p)=(0.2573815659097741+0j) \epsilon_r(v)=(0.14638623476797702+0j)$
# $\sigma_i=49$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(50.97922518278103-24.517762630786116j)  \epsilon_r=(0.7490366736310106+0j) \epsilon_r(\omega)=0.4438561133177734  \epsilon_r(p)=(0.901311883101984+0j) \epsilon_r(v)=(0.9019420244732747+0j)$
# Computing for sigma_i = 50.00 (piecewise)
# $\sigma_i=50$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.779445327763096-1.7858358960162932j)  \epsilon_r=(0.15249078968405774+0j) \epsilon_r(\omega)=0.03631681180064719  \epsilon_r(p)=(0.2686336729720673+0j) \epsilon_r(v)=(0.15252188427945879+0j)$
# $\sigma_i=50$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(48.22631815056603-25.018931273435488j)  \epsilon_r=(0.7576053494340576+0j) \epsilon_r(\omega)=0.45539736285315324  \epsilon_r(p)=(0.9055151338538007+0j) \epsilon_r(v)=(0.9119035515952185+0j)$
# Computing for sigma_i = 51.00 (piecewise)
# $\sigma_i=51$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.77793035916826-1.7681116363486415j)  \epsilon_r=(0.1587298016776701+0j) \epsilon_r(\omega)=0.03750329791363962  \epsilon_r(p)=(0.2800168608829203+0j) \epsilon_r(v)=(0.15866924623645043+0j)$
# $\sigma_i=51$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=3  \omega=(43.85805221941371-21.804290568674766j)  \epsilon_r=(0.7494160929134673+0j) \epsilon_r(\omega)=0.40997882126363644  \epsilon_r(p)=(0.9056466508672979+0j) \epsilon_r(v)=(0.9326228066094677+0j)$
# Computing for sigma_i = 52.00 (piecewise)
# $\sigma_i=52$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.776258474877828-1.7506151606283453j)  \epsilon_r=(0.16501041826634402+0j) \epsilon_r(\omega)=0.03868226187975041  \epsilon_r(p)=(0.29152517039284187+0j) \epsilon_r(v)=(0.16482382252643976+0j)$
# $\sigma_i=52$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=3  \omega=(43.95123396996129-19.09260074954439j)  \epsilon_r=(0.7304663927201167+0j) \epsilon_r(\omega)=0.35848692414136507  \epsilon_r(p)=(0.8973059972430983+0j) \epsilon_r(v)=(0.9356062567758867+0j)$
# Computing for sigma_i = 53.00 (piecewise)
# $\sigma_i=53$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.774450445238152-1.7333497759830907j)  \epsilon_r=(0.17132911977635293+0j) \epsilon_r(\omega)=0.039853078965121455  \epsilon_r(p)=(0.30315287753905007+0j) \epsilon_r(v)=(0.1709814028248873+0j)$
# $\sigma_i=53$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=3  \omega=(44.04423858460754-17.436355095672354j)  \epsilon_r=(0.7189723783008284+0j) \epsilon_r(\omega)=0.32715092808435325  \epsilon_r(p)=(0.8916370360640503+0j) \epsilon_r(v)=(0.9381291707540815+0j)$
# Computing for sigma_i = 54.00 (piecewise)
# $\sigma_i=54$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.772525030125832-1.7163176898968677j)  \epsilon_r=(0.17768257421656014+0j) \epsilon_r(\omega)=0.04101518458241413  \epsilon_r(p)=(0.3148944913232396+0j) \epsilon_r(v)=(0.17713804674402678+0j)$
# $\sigma_i=54$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=3  \omega=(44.13566025367333-16.1849981601905j)  \epsilon_r=(0.7103779624332265+0j) \epsilon_r(\omega)=0.30353598351125877  \epsilon_r(p)=(0.8870627265536954+0j) \epsilon_r(v)=(0.9405351772347255+0j)$
# Computing for sigma_i = 55.00 (piecewise)
# $\sigma_i=55$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.770499145382548-1.6995201840800058j)  \epsilon_r=(0.18406762985043382+0j) \epsilon_r(\omega)=0.042168070890721714  \epsilon_r(p)=(0.3267447506360832+0j) \epsilon_r(v)=(0.18329006802449652+0j)$
# $\sigma_i=55$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=3  \omega=(44.22546678655797-15.164803726750614j)  \epsilon_r=(0.703464724383682+0j) \epsilon_r(\omega)=0.28432220400702346  \epsilon_r(p)=(0.8831630736999375+0j) \epsilon_r(v)=(0.9429088954440852+0j)$
# Computing for sigma_i = 56.00 (piecewise)
# $\sigma_i=56$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.768388020382439-1.6829577606507138j)  \epsilon_r=(0.1904813080750734+0j) \epsilon_r(\omega)=0.04331128347731005  \epsilon_r(p)=(0.33869862044893223+0j) \epsilon_r(v)=(0.18943402029897805+0j)$
# $\sigma_i=56$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=3  \omega=(44.31367522417464-14.29852447527995j)  \epsilon_r=(0.6976917560387218+0j) \epsilon_r(\omega)=0.2680345287437295  \epsilon_r(p)=(0.8797547650511172+0j) \epsilon_r(v)=(0.9452859743213187+0j)$
# Computing for sigma_i = 57.00 (piecewise)
# $\sigma_i=57$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.76620534585051-1.6666302652214255j)  \epsilon_r=(0.1969207965094481+0j) \epsilon_r(\omega)=0.04444441812367854  \epsilon_r(p)=(0.3507512873242996+0j) \epsilon_r(v)=(0.19556668408036618+0j)$
# $\sigma_i=57$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=3  \omega=(44.40030677508646-13.543817844589963j)  \epsilon_r=(0.6927638128331243+0j) \epsilon_r(\omega)=0.25386517208324866  \epsilon_r(p)=(0.8767410032942685+0j) \epsilon_r(v)=(0.9476852631218557+0j)$
# Computing for sigma_i = 58.00 (piecewise)
# $\sigma_i=58$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.763963411557-1.6505369907213245j)  \epsilon_r=(0.20338344223251598+0j) \epsilon_r(\omega)=0.045567117661356814  \epsilon_r(p)=(0.3628981543163651+0j) \epsilon_r(v)=(0.2016850547198261+0j)$
# $\sigma_i=58$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=3  \omega=(44.48538613519632-12.874505965881363j)  \epsilon_r=(0.6884996880499622+0j) \epsilon_r(\omega)=0.24131524977366853  \epsilon_r(p)=(0.8740655511255101+0j) \epsilon_r(v)=(0.9501182632507081+0j)$
# Computing for sigma_i = 59.00 (piecewise)
# $\sigma_i=59$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.761673233866338-1.6346767651422875j)  \epsilon_r=(0.20986674513895004+0j) \epsilon_r(\omega)=0.04667906892413854  \epsilon_r(p)=(0.37513483534340797+0j) \epsilon_r(v)=(0.20778633114930364+0j)$
# $\sigma_i=59$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=3  \omega=(44.56894475540929-12.273066962508551j)  \epsilon_r=(0.684779387946586+0j) \epsilon_r(\omega)=0.23005119420936146  \epsilon_r(p)=(0.8716941954938185+0j) \epsilon_r(v)=(0.9525927741365782+0j)$
# Computing for sigma_i = 60.00 (piecewise)
# $\sigma_i=60$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.759344673361708-1.619048025854731j)  \epsilon_r=(0.21636835139878333+0j) \epsilon_r(\omega)=0.04777999980367207  \epsilon_r(p)=(0.38745714911832724+0j) \epsilon_r(v)=(0.21386790527435065+0j)$
# $\sigma_i=60$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=3  \omega=(44.65102447800238-11.727088000490514j)  \epsilon_r=(0.6815191159238069+0j) \epsilon_r(\omega)=0.21983692063270793  \epsilon_r(p)=(0.8696059058776462+0j) \epsilon_r(v)=(0.9551145212610663+0j)$
# Computing for sigma_i = 61.00 (piecewise)
# $\sigma_i=61$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.756986542926072-1.6036488826887743j)  \epsilon_r=(0.22288604701965276+0j) \epsilon_r(\omega)=0.04886967641478789  \epsilon_r(p)=(0.399861112723234+0j) \epsilon_r(v)=(0.21992735192093632+0j)$
# $\sigma_i=61$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=2  \omega=(44.73168102557986-11.227392027320759j)  \epsilon_r=(0.6786580044112626+0j) \epsilon_r(\omega)=0.21049798653995413  \epsilon_r(p)=(0.8677880942814837+0j) \epsilon_r(v)=(0.9576879324123502+0j)$
# Computing for sigma_i = 62.00 (piecewise)
# $\sigma_i=62$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.754606706761736-1.588477171601197j)  \epsilon_r=(0.22941775151805557+0j) \epsilon_r(\omega)=0.04994790037599125  \epsilon_r(p)=(0.41234293491073853+0j) \epsilon_r(v)=(0.22596241926743696+0j)$
# $\sigma_i=62$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=2  \omega=(44.81098716863158-10.766964976816869j)  \epsilon_r=(0.6761504610975161+0j) \epsilon_r(\omega)=0.20190104733843367  \epsilon_r(p)=(0.866233838490351+0j) \epsilon_r(v)=(0.9603164974637637+0j)$
# Computing for sigma_i = 63.00 (piecewise)
# $\sigma_i=63$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.752212170888052-1.5735305004374236j)  \epsilon_r=(0.23596151171047747+0j) \epsilon_r(\omega)=0.05101450620937859  \epsilon_r(p)=(0.4248990092091899+0j) \epsilon_r(v)=(0.23197101971286402+0j)$
# $\sigma_i=63$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=2  \omega=(44.88903545806919-10.340302503467054j)  \epsilon_r=(0.6739614517883533+0j) \epsilon_r(\omega)=0.1939413260893524  \epsilon_r(p)=(0.8649401328776001+0j) \epsilon_r(v)=(0.9630028963981078+0j)$
# Computing for sigma_i = 64.00 (piecewise)
# $\sigma_i=64$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.749809165684352-1.5588062880415363j)  \epsilon_r=(0.24251549563727776+0j) \epsilon_r(\omega)=0.05206935886289855  \epsilon_r(p)=(0.43752590690247634+0j) \epsilon_r(v)=(0.2379512211464584+0j)$
# $\sigma_i=64$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=2  \omega=(44.96594044198435-9.942992722858394j)  \epsilon_r=(0.6720634275582524+0j) \epsilon_r(\omega)=0.18653459000074712  \epsilon_r(p)=(0.8639067122370088+0j) \epsilon_r(v)=(0.9657489804370012+0j)$
# Computing for sigma_i = 65.00 (piecewise)
# $\sigma_i=65$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.747403221050877-1.5443017977543607j)  \epsilon_r=(0.24907798663272354+0j) \epsilon_r(\omega)=0.053112351356647  \epsilon_r(p)=(0.4502203699478336+0j) \epsilon_r(v)=(0.24390123859369003+0j)$
# $\sigma_i=65$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=2  \omega=(45.04184030557817-9.571439477343414j)  \epsilon_r=(0.6704342207601648+0j) \epsilon_r(\omega)=0.17961180947901476  \epsilon_r(p)=(0.8631352067007162+0j) \epsilon_r(v)=(0.9685556461007635+0j)$
# Computing for sigma_i = 66.00 (piecewise)
# $\sigma_i=66$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.744999234751287-1.5300141661648503j)  \epsilon_r=(0.25564737755387795+0j) \epsilon_r(\omega)=0.05414340255364958  \epsilon_r(p)=(0.46297930388759656+0j) \epsilon_r(v)=(0.24981942622038772+0j)$
# $\sigma_i=66$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=2  \omega=(45.1168978659811-9.222673322294222j)  \epsilon_r=(0.6690555324203611+0j) \epsilon_r(\omega)=0.1731154913554269  \epsilon_r(p)=(0.8626284864875738+0j) \epsilon_r(v)=(0.9714226194180829+0j)$
# Computing for sigma_i = 67.00 (piecewise)
# $\sigma_i=67$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.742601534481159-1.5159404278355415j)  \epsilon_r=(0.2622221651797735+0j) \epsilon_r(\omega)=0.05516245505447765  \epsilon_r(p)=(0.47579977080360253+0j) \epsilon_r(v)=(0.2557042696812403+0j)$
# $\sigma_i=67$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=2  \omega=(45.19130080526319-8.894219554541667j)  \epsilon_r=(0.6679117871949997+0j) \epsilon_r(\omega)=0.1669971012243359  \epsilon_r(p)=(0.8623901049906718+0j) \epsilon_r(v)=(0.9743481553699913+0j)$
# Computing for sigma_i = 68.00 (piecewise)
# $\sigma_i=68$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.740213934181348-1.5020775366035055j)  \epsilon_r=(0.2688009447905233+0j) \epsilon_r(\omega)=0.05616947321408226  \epsilon_r(p)=(0.488678982355814+0j) \epsilon_r(v)=(0.2615543788016737+0j)$
# $\sigma_i=68$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=2  \omega=(45.26526092296245-8.584004723229471j)  \epsilon_r=(0.6669892160255433+0j) \epsilon_r(\omega)=0.16121522255981616  \epsilon_r(p)=(0.8624237737919143+0j) \epsilon_r(v)=(0.9773286517248992+0j)$
# Computing for sigma_i = 69.00 (piecewise)
# $\sigma_i=69$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.73783978508559-1.4884223839598734j)  \epsilon_r=(0.27538240493417215+0j) \epsilon_r(\omega)=0.05716444127838987  \epsilon_r(p)=(0.5016142929402657+0j) \epsilon_r(v)=(0.267368480583861+0j)$
# $\sigma_i=69$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=2  \omega=(45.33901202433246-8.29028998769088j)  \epsilon_r=(0.6662750756707929+0j) \epsilon_r(\omega)=0.15573423481795245  \epsilon_r(p)=(0.8627328162011165+0j) \epsilon_r(v)=(0.9803581759933099+0j)$
# Computing for sigma_i = 70.00 (piecewise)
# $\sigma_i=70$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.735482021960255-1.4749718149296613j)  \epsilon_r=(0.2819653223871108+0j) \epsilon_r(\omega)=0.05814736163751126  \epsilon_r(p)=(0.5146031929953384+0j) \epsilon_r(v)=(0.2731454125284828+0j)$
# $\sigma_i=70$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=2  \omega=(45.41280582936548-8.01162373692976j)  \epsilon_r=(0.6657569462889847+0j) \epsilon_r(\omega)=0.15052337384854328  \epsilon_r(p)=(0.8633195541967614+0j) \epsilon_r(v)=(0.9834279108216495+0j)$
# Computing for sigma_i = 71.00 (piecewise)
# $\sigma_i=71$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.733143204962188-1.461722641806491j)  \epsilon_r=(0.28854855731197415+0j) \epsilon_r(\omega)=0.0591182531918452  \epsilon_r(p)=(0.527643302479855+0j) \epsilon_r(v)=(0.2788841162642223+0j)$
# $\sigma_i=71$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=2  \omega=(45.48690500505459-7.746808213111842j)  \epsilon_r=(0.665422073749675+0j) \epsilon_r(\omega)=0.1455560880190787  \epsilon_r(p)=(0.8641845931296853+0j) \epsilon_r(v)=(0.9865255401002614+0j)$
# Computing for sigma_i = 72.00 (piecewise)
# $\sigma_i=72$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.73082555750866-1.4486716560408759j)  \epsilon_r=(0.29513104861520023+0j) \epsilon_r(\omega)=0.06007714982693445  \epsilon_r(p)=(0.5407323645416403+0j) \epsilon_r(v)=(0.28458363147702603+0j)$
# $\sigma_i=72$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=2  \omega=(45.56157214478734-7.494876057182323j)  \epsilon_r=(0.6652567497517146+0j) \epsilon_r(\omega)=0.14080963338253294  \epsilon_r(p)=(0.8653259858421558+0j) \epsilon_r(v)=(0.9896346300304548+0j)$
# Computing for sigma_i = 73.00 (piecewise)
# $\sigma_i=73$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.728531000522489-1.43581563853473j)  \epsilon_r=(0.3017118095047645+0j) \epsilon_r(\omega)=0.061024098992588344  \epsilon_r(p)=(0.5538682393907399+0j) \epsilon_r(v)=(0.29024309013096544+0j)$
# $\sigma_i=73$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=2  \omega=(45.637053377478466-7.255072996671385j)  \epsilon_r=(0.6652457556552559+0j) \epsilon_r(\omega)=0.13626486529022505  \epsilon_r(p)=(0.8667382910653956+0j) \epsilon_r(v)=(0.9927341106101473+0j)$
# Computing for sigma_i = 74.00 (piecewise)
# $\sigma_i=74$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.726261183385942-1.423151368556209j)  \epsilon_r=(0.30828992324721405+0j) \epsilon_r(\omega)=0.061959160381570934  \epsilon_r(p)=(0.5670488983877618+0j) \epsilon_r(v)=(0.29586171097230934+0j)$
# $\sigma_i=74$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=2  \omega=(45.713555538953294-7.026842504580114j)  \epsilon_r=(0.665371937834091+0j) \epsilon_r(\omega)=0.13190618237520935  \epsilon_r(p)=(0.8684115984052327+0j) \epsilon_r(v)=(0.9957980327218311+0j)$
# Computing for sigma_i = 75.00 (piecewise)
# $\sigma_i=75$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.72401751190878-1.4106756314569382j)  \epsilon_r=(0.31486453912182144+0j) \epsilon_r(\omega)=0.06288240470301118  \epsilon_r(p)=(0.580272418354391+0j) \epsilon_r(v)=(0.30143879430806203+0j)$
# $\sigma_i=75$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=2  \omega=(45.791216858739496-6.809807455009725j)  \epsilon_r=(0.6656160292182258+0j) \epsilon_r(\omega)=0.12772156076432625  \epsilon_r(p)=(0.8703306770000051+0j) \epsilon_r(v)=(0.9987958498903463+0j)$
# Computing for sigma_i = 76.00 (piecewise)
# $\sigma_i=76$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.721801173589668-1.3983852253472078j)  \epsilon_r=(0.3214348685686501+0j) \epsilon_r(\omega)=0.06379391254560952  \epsilon_r(p)=(0.5935369761103646+0j) \epsilon_r(v)=(0.3069737170499763+0j)$
# $\sigma_i=76$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=2  \omega=(45.870073285683475-6.60374319356545j)  \epsilon_r=(0.665956866716017+0j) \epsilon_r(\omega)=0.12370258374294718  \epsilon_r(p)=(0.8724745035891869+0j) \epsilon_r(v)=(1.001693512815917+0j)$
# Computing for sigma_i = 77.00 (piecewise)
# $\sigma_i=77$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.71961316042554-1.3862769668619426j)  \epsilon_r=(0.32800018152638555+0j) \epsilon_r(\omega)=0.06469377332573792  \epsilon_r(p)=(0.6068408432386627+0j) \epsilon_r(v)=(0.312465928014756+0j)$
# $\sigma_i=77$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=2  \omega=(45.95002589792809-6.408537095426932j)  \epsilon_r=(0.6663721443874694+0j) \epsilon_r(\omega)=0.11984433665838094  \epsilon_r(p)=(0.8748164942891515+0j) \epsilon_r(v)=(1.0044556022148758+0j)$
# Computing for sigma_i = 78.00 (piecewise)
# $\sigma_i=78$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.717454289500735-1.3743476961317735j)  \epsilon_r=(0.3345598029550745+0j) \epsilon_r(\omega)=0.06558208431555516  \epsilon_r(p)=(0.6201823810786748+0j) \epsilon_r(v)=(0.3179149434709935+0j)$
# $\sigma_i=78$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=2  \omega=(46.0308183505883-6.224132844521139j)  \epsilon_r=(0.6668397483286356+0j) \epsilon_r(\omega)=0.11614502516609607  \epsilon_r(p)=(0.8773257269582102+0j) \epsilon_r(v)=(1.0070484928616004+0j)$
# Computing for sigma_i = 79.00 (piecewise)
# $\sigma_i=79$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.715325221566818-1.3625942810576621j)  \epsilon_r=(0.3411131095383363+0j) \epsilon_r(\omega)=0.06645894974635506  \epsilon_r(p)=(0.6335600359454029+0j) \epsilon_r(v)=(0.3233203429232512+0j)$
# $\sigma_i=79$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=2  \omega=(46.112034765785914-6.050463732284586j)  \epsilon_r=(0.6673395292941292+0j) \epsilon_r(\omega)=0.11260522158718118  \epsilon_r(p)=(0.8799692268846143+0j) \epsilon_r(v)=(1.0094441394105922+0j)$
# Computing for sigma_i = 80.00 (piecewise)
# ...
# $\sigma_i=76$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.31602321948798-2.2384506194316307j)  \epsilon_r=(0.017713492059776133+0j) \epsilon_r(\omega)=0.0012963195659054308  \epsilon_r(p)=(0.026927217274276664+0j) \epsilon_r(v)=(0.024916939339146307+0j)$
# Computing for sigma_i = 77.00 (piecewise)
# $\sigma_i=77$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.58234525446761-2.174079871260933j)  \epsilon_r=(0.007961222487509283+0j) \epsilon_r(\omega)=0.0022044613567418804  \epsilon_r(p)=(0.013617763718842112+0j) \epsilon_r(v)=(0.008061442386943861+0j)$
# $\sigma_i=77$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.3187941678225-2.238004806755827j)  \epsilon_r=(0.017996068064593092+0j) \epsilon_r(\omega)=0.001334046598628648  \epsilon_r(p)=(0.027754787843019383+0j) \epsilon_r(v)=(0.024899369752131247+0j)$
# Computing for sigma_i = 78.00 (piecewise)
# $\sigma_i=78$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.582873099615352-2.1728092670377666j)  \epsilon_r=(0.008355609299080533+0j) \epsilon_r(\omega)=0.00231004609619314  \epsilon_r(p)=(0.014277846121995489+0j) \epsilon_r(v)=(0.008478935679052974+0j)$
# $\sigma_i=78$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.321608951920325-2.2374693870965086j)  \epsilon_r=(0.01829254744737377+0j) \epsilon_r(\omega)=0.001372672664096963  \epsilon_r(p)=(0.028610327810788923+0j) \epsilon_r(v)=(0.024894641867235428+0j)$
# Computing for sigma_i = 79.00 (piecewise)
# $\sigma_i=79$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.583406259707868-2.1714950689090826j)  \epsilon_r=(0.008762658274730351+0j) \epsilon_r(\omega)=0.0024189100747679312  \epsilon_r(p)=(0.014959216682889125+0j) \epsilon_r(v)=(0.008909848066533997+0j)$
# $\sigma_i=79$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.3244647581042-2.2368422870068896j)  \epsilon_r=(0.018603410875696703+0j) \epsilon_r(\omega)=0.0014121983962838793  \epsilon_r(p)=(0.029493883400219724+0j) \epsilon_r(v)=(0.024904150830586506+0j)$
# Computing for sigma_i = 80.00 (piecewise)
# $\sigma_i=80$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.583944395052104-2.1701368372224805j)  \epsilon_r=(0.009182510920067973+0j) \epsilon_r(\omega)=0.0025310824781250196  \epsilon_r(p)=(0.015662134354764733+0j) \epsilon_r(v)=(0.009354315927314168+0j)$
# $\sigma_i=80$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.32735865360109-2.2361215855001615j)  \epsilon_r=(0.018929132811420873+0j) \epsilon_r(\omega)=0.001452623164707417  \epsilon_r(p)=(0.03040546718572062+0j) \epsilon_r(v)=(0.024929308083834582+0j)$
# Computing for sigma_i = 81.00 (piecewise)
# $\sigma_i=81$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.584487158828045-2.1687341622403866j)  \epsilon_r=(0.00961530275911043+0j) \epsilon_r(\omega)=0.0026465903751428637  \epsilon_r(p)=(0.01638684839419839+0j) \epsilon_r(v)=(0.009812469507990036+0j)$
# $\sigma_i=81$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.330287596407366-2.2353055234893136j)  \epsilon_r=(0.019270178509027836+0j) \epsilon_r(\omega)=0.0014939450974185682  \epsilon_r(p)=(0.03134506003821481+0j) \epsilon_r(v)=(0.024971530391450135+0j)$
# Computing for sigma_i = 82.00 (piecewise)
# $\sigma_i=82$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.585034197739686-2.1672866647575977j)  \epsilon_r=(0.01006116316132668+0j) \epsilon_r(\omega)=0.00276545867971198  \epsilon_r(p)=(0.017133598132863342+0j) \epsilon_r(v)=(0.010284432671404716+0j)$
# $\sigma_i=82$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.33324844606115-2.2343925123901998j)  \epsilon_r=(0.019627000683345056+0j) \epsilon_r(\omega)=0.0015361611101664546  \epsilon_r(p)=(0.03231261305992122+0j) \epsilon_r(v)=(0.025032227879947497+0j)$
# Computing for sigma_i = 83.00 (piecewise)
# $\sigma_i=83$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.58558515268474-2.165793996657637j)  \epsilon_r=(0.010520215184490384+0j) \epsilon_r(\omega)=0.0028877101166771644  \epsilon_r(p)=(0.01790261276709072+0j) \epsilon_r(v)=(0.010770322669703273+0j)$
# $\sigma_i=83$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.33623797527055-2.233381141785106j)  \epsilon_r=(0.020000035913699362+0j) \epsilon_r(\omega)=0.00157926694205515  \epsilon_r(p)=(0.03330804951364204+0j) \epsilon_r(v)=(0.0251127912854009+0j)$
# Computing for sigma_i = 84.00 (piecewise)
# $\sigma_i=84$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.586139659439235-2.1642558414050583j)  \epsilon_r=(0.010992575433107313+0j) \epsilon_r(\omega)=0.0030133651920322756  \epsilon_r(p)=(0.01869411116578562+0j) \epsilon_r(v)=(0.011270249941504048+0j)$
# $\sigma_i=84$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.33925288226408-2.23227018603802j)  \epsilon_r=(0.02038970085684593+0j) \epsilon_r(\omega)=0.0016232571966310124  \epsilon_r(p)=(0.03433126672241838+0j) \epsilon_r(v)=(0.025214578651488403+0j)$
# Computing for sigma_i = 85.00 (piecewise)
# $\sigma_i=85$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.586697349356486-2.162671914472934j)  \epsilon_r=(0.011478353932191581+0j) \epsilon_r(\omega)=0.0031424421674755127  \epsilon_r(p)=(0.019508301697148844+0j) \epsilon_r(v)=(0.011784317931950393+0j)$
# $\sigma_i=85$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.34228980377182-2.2310586097922287j)  \epsilon_r=(0.020796388370828582+0j) \epsilon_r(\omega)=0.0016681253884710495  \epsilon_r(p)=(0.03538213794597018+0j) \epsilon_r(v)=(0.02533890177804452+0j)$
# Computing for sigma_i = 86.00 (piecewise)
# $\sigma_i=86$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.587257850076153-2.161041963703969j)  \epsilon_r=(0.01197765401604629+0j) \epsilon_r(\omega)=0.0032749570393344257  \epsilon_r(p)=(0.0203453820743267+0j) \epsilon_r(v)=(0.01231262293447775+0j)$
# $\sigma_i=86$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.34534532850131-2.229745572265218j)  \epsilon_r=(0.021220463654849676+0j) \epsilon_r(\omega)=0.0017138639944192717  \epsilon_r(p)=(0.03646051422017824+0j) \epsilon_r(v)=(0.025487012749951517+0j)$
# Computing for sigma_i = 87.00 (piecewise)
# $\sigma_i=87$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.587820786241855-2.1593657696042436j)  \epsilon_r=(0.012490572231943293+0j) \epsilon_r(\omega)=0.0034109235219495606  \epsilon_r(p)=(0.02120553922040431+0j) \epsilon_r(v)=(0.012855253953476012+0j)$
# $\sigma_i=87$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.348416010976266-2.228330430298297j)  \epsilon_r=(0.021662260525537706+0j) \epsilon_r(\omega)=0.0017604645090348288  \epsilon_r(p)=(0.03756622615908002+0j) \epsilon_r(v)=(0.025660090908498277+0j)$
# Computing for sigma_i = 88.00 (piecewise)
# $\sigma_i=88$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.588385780224108-2.157643145569003j)  \epsilon_r=(0.01301719825840775+0j) \epsilon_r(\omega)=0.0035503530355122897  \epsilon_r(p)=(0.02208894915275181+0j) \epsilon_r(v)=(0.013412292586959156+0j)$
# $\sigma_i=88$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.35149838559758-2.226812740119517j)  \epsilon_r=(0.02212207794969092+0j) \epsilon_r(\omega)=0.0018079175035800794  \epsilon_r(p)=(0.038699085713644756+0j) \epsilon_r(v)=(0.02585923063184793+0j)$
# Computing for sigma_i = 89.00 (piecewise)
# $\sigma_i=89$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.588952452845925-2.155873938040046j)  \epsilon_r=(0.013557614837957848+0j) \epsilon_r(\omega)=0.0036932546983704457  \epsilon_r(p)=(0.022995776886914232+0j) \epsilon_r(v)=(0.013983812928588872+0j)$
# $\sigma_i=89$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.35458898078563-2.2251922578094874j)  \epsilon_r=(0.022600176952855877+0j) \epsilon_r(\omega)=0.0018562126880072238  \epsilon_r(p)=(0.03985888788654565+0j) \epsilon_r(v)=(0.026085430284014756+0j)$
# Computing for sigma_i = 90.00 (piecewise)
# $\sigma_i=90$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.589520424108477-2.154058026594494j)  \epsilon_r=(0.01411189772405097+0j) \epsilon_r(\omega)=0.0038396353238047795  \epsilon_r(p)=(0.023926176360012957+0j) \epsilon_r(v)=(0.014569881488335174+0j)$
# $\sigma_i=90$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.357684333055374-2.2234689384672772j)  \epsilon_r=(0.023096778009645165+0j) \epsilon_r(\omega)=0.0019053389751676963  \epsilon_r(p)=(0.04104541239629368+0j) \epsilon_r(v)=(0.026339582657474124+0j)$
# Computing for sigma_i = 91.00 (piecewise)
# $\sigma_i=91$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.590089313913968-2.152195323965239j)  \epsilon_r=(0.014680115642050576+0j) \epsilon_r(\omega)=0.003989499421236095  \epsilon_r(p)=(0.02488029037368892+0j) \epsilon_r(v)=(0.01517055713122672+0j)$
# $\sigma_i=91$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.36078100087678-2.2216429341000157j)  \epsilon_r=(0.023612059006387333+0j) \epsilon_r(\omega)=0.001955284546493065  \epsilon_r(p)=(0.042258425286116626+0j) \epsilon_r(v)=(0.026622467186552316+0j)$
# Computing for sigma_i = 92.00 (piecewise)
# $\sigma_i=92$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.590658742782692-2.1502857759936442j)  \epsilon_r=(0.015262330263830063+0j) \epsilon_r(\omega)=0.004142849201799587  \epsilon_r(p)=(0.025858250556239665+0j) \epsilon_r(v)=(0.015785891033450943+0j)$
# $\sigma_i=92$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.36387557820639-2.219714590278718j)  \epsilon_r=(0.024146153850044934+0j) \epsilon_r(\omega)=0.0020060369189411112  \epsilon_r(p)=(0.0434976804842601+0j) \epsilon_r(v)=(0.02693474414693359+0j)$
# Computing for sigma_i = 93.00 (piecewise)
# $\sigma_i=93$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.591228332562768-2.1483293615147585j)  \epsilon_r=(0.015858596196062644+0j) \epsilon_r(\omega)=0.004299684588302941  \epsilon_r(p)=(0.02686017734427633+0j) \epsilon_r(v)=(0.016415926655608665+0j)$
# $\sigma_i=93$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.36696470752694-2.217684441611229j)  \epsilon_r=(0.024699151759091688+0j) \epsilon_r(\omega)=0.0020575830118894716  \epsilon_r(p)=(0.04476292129708529+0j) \epsilon_r(v)=(0.027276950968300313+0j)$
# Computing for sigma_i = 94.00 (piecewise)
# $\sigma_i=94$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.591797707128013-2.1463260921767686j)  \epsilon_r=(0.016468960981441145+0j) \epsilon_r(\omega)=0.004460003229371298  \epsilon_r(p)=(0.027886179982930165+0j) \epsilon_r(v)=(0.017060699732021976+0j)$
# $\sigma_i=94$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.37004509230137-2.215553206110072j)  \epsilon_r=(0.02527109725715238+0j) \epsilon_r(\omega)=0.0021099092138861008  \epsilon_r(p)=(0.046053881843701634+0j) \epsilon_r(v)=(0.0276495007138694+0j)$
# Computing for sigma_i = 95.00 (piecewise)
# $\sigma_i=95$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.592366493063315-2.1442760121953968j)  \epsilon_r=(0.01709346511294993+0j) \epsilon_r(\omega)=0.004623800517796908  \epsilon_r(p)=(0.02893635654497791+0j) \epsilon_r(v)=(0.01772023827607497+0j)$
# $\sigma_i=95$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=1  \omega=(50.37311350872526-2.213321778537013j)  \epsilon_r=(0.02586199085432553+0j) \epsilon_r(\omega)=0.002163001448497143  \epsilon_r(p)=(0.04737028842544673+0j) \epsilon_r(v)=(0.02805268268903271+0j)$
# Computing for sigma_i = 96.00 (piecewise)
# $\sigma_i=96$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.592934320334141-2.1421791980449933j)  \epsilon_r=(0.017732142060627763+0j) \epsilon_r(\omega)=0.004791069612937986  \epsilon_r(p)=(0.030010793968181897+0j) \epsilon_r(v)=(0.018394562600763404+0j)$
# $\sigma_i=96$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.376166816679195-2.2109912228251263j)  \epsilon_r=(0.026471790375239695+0j) \epsilon_r(\omega)=0.002216845238642332  \epsilon_r(p)=(0.04871186082487691+0j) \epsilon_r(v)=(0.028486665062199844+0j)$
# Computing for sigma_i = 97.00 (piecewise)
# $\sigma_i=97$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.593500822937756-2.1400357580883957j)  \epsilon_r=(0.018385018310385356+0j) \epsilon_r(\omega)=0.004961801467023043  \epsilon_r(p)=(0.031109568110293473+0j) \epsilon_r(v)=(0.019083685353839558+0j)$
# $\sigma_i=97$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.379201969812115-2.2085627636774348j)  \epsilon_r=(0.027100412873420788+0j) \epsilon_r(\omega)=0.0022714257691152004  \epsilon_r(p)=(0.05007831353663558+0j) \epsilon_r(v)=(0.028951499314511586+0j)$
# Computing for sigma_i = 98.00 (piecewise)
# $\sigma_i=98$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.594065639534474-2.137845832146988j)  \epsilon_r=(0.019052113414729947+0j) \epsilon_r(\omega)=0.005135984855286033  \epsilon_r(p)=(0.032232743821658895+0j) \epsilon_r(v)=(0.01978761156724492+0j)$
# $\sigma_i=98$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.382216024676346-2.20603777746657j)  \epsilon_r=(0.02774773704802654+0j) \epsilon_r(\omega)=0.002326727946584579  \epsilon_r(p)=(0.05146935692124772+0j) \epsilon_r(v)=(0.029447126276247328+0j)$
# Computing for sigma_i = 99.00 (piecewise)
# $\sigma_i=99$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.594628414056398-2.135609591013883j)  \epsilon_r=(0.019733440054673326+0j) \epsilon_r(\omega)=0.005313606409720915  \epsilon_r(p)=(0.033380375034374854+0j) \epsilon_r(v)=(0.020506338719924216+0j)$
# $\sigma_i=99$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.38520614888847-2.203417782541865j)  \epsilon_r=(0.028413606074279025+0j) \epsilon_r(\omega)=0.0023827364571099583  \epsilon_r(p)=(0.052884698289675375+0j) \epsilon_r(v)=(0.02997338347605175+0j)$
# Computing for sigma_i = 100.00 (piecewise)
# $\sigma_i=100$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.59518879629234-2.133327235911978j)  \epsilon_r=(0.02042900411269965+0j) \epsilon_r(\omega)=0.005494650656366422  \epsilon_r(p)=(0.03455250486795303+0j) \epsilon_r(v)=(0.021239856813779504+0j)$
# $\sigma_i=100$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.38816962825945-2.20070442906735j)  \epsilon_r=(0.029097830742099075+0j) \epsilon_r(\omega)=0.0024394358203913874  \epsilon_r(p)=(0.05432404290620938+0j) \epsilon_r(v)=(0.030530013499696456+0j)$
# Computing for sigma_i = 101.00 (piecewise)
# $\sigma_i=101$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.595746442446346-2.130998997900131j)  \epsilon_r=(0.021138804756017485+0j) \epsilon_r(\omega)=0.0056791000558817995  \epsilon_r(p)=(0.03574916575034937+0j) \epsilon_r(v)=(0.021988148461821285+0j)$
# $\sigma_i=101$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.391103872900324-2.19789948851183j)  \epsilon_r=(0.029800192807607984+0j) \epsilon_r(\omega)=0.00249681044095904  \epsilon_r(p)=(0.055787094919783224+0j) \epsilon_r(v)=(0.03111667306208168+0j)$

# %%
colors = ['tab:green', 'tab:orange', 'tab:blue']
linestyles = {0: '--', 3: ':'}
labels = {0: r'$\omega_0$', 3: r'$\omega_3$'}

fig, ax = plt.subplots(figsize=(7, 5))

key = 'tot'   # ← só total
err_tot = rel_err_total_sigma_sweep

for j in [0, 3]:            # modos físicos
    for i, N_index in enumerate(N):
        col = colors[i % len(colors)]
        ls = linestyles[j]

        errs = err_tot[j][N_index]

        ax.plot(
            sigma_sweep,
            errs,
            color=col,
            linestyle=ls,
            label=f"{labels[j]}, N={N_index}"
        )

        # mínimo
        k = np.argmin(errs)
        ax.plot(
            sigma_sweep[k],
            errs[k],
            '*',
            color=col,
            markersize=8
        )

ax.set_yscale('log')
ax.set_xlabel(r'$\sigma_0$')
ax.set_ylabel(r'$\epsilon_r$')
ax.grid(True)

# lenda sen duplicados
handles, labels_leg = ax.get_legend_handles_labels()
by_label = dict(zip(labels_leg, handles))
ax.legend(by_label.values(), by_label.keys(), ncol=2)

# plt.suptitle(
#     f'$\sigma_0$ optimization depending on $\omega$ and N values. PML profile {pml_profile}.',
#     fontsize=14
# )

plt.tight_layout()
# plt.savefig(f"sigma_optimization_total_{pml_profile}.png", dpi=300)
plt.savefig(f"1D_bicapa_optimo_{pml_profile}.pdf", dpi=300)

plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
eig_number=0  # modo físico 0
N_i=N[0]         # refinamento N=4 (0,1,2 → 2,3,4)

sigma_of_interest=1
indice = np.argmin(np.abs(sigma_sweep - sigma_of_interest))
print("Sigma of interest: ", sigma_sweep[indice])
print("Relative error total: ", rel_err_total_sigma_sweep[eig_number][N_i][indice])

sigma_0=sigma_sweep[indice]

idx_min_err = np.argmin(rel_err_total_sigma_sweep[eig_number][N_i])
p_approx = approx_p[eig_number][N_i][indice]
v_approx = approx_v[eig_number][N_i][indice]
p_exact = exact_p[eig_number][N_i][indice]
v_exact = exact_v[eig_number][N_i][indice]

mesh = create_interval(MPI.COMM_WORLD, int((Lx + pml_thickness) / h[N_i]), [0, Lx + pml_thickness])

bb = bb_tree(mesh, mesh.topology.dim)

# Extract FunctionSpace objects from the approximated functions
Q = p_approx.ufl_function_space()
V = v_approx.ufl_function_space()

fig, axes = plt.subplots(1, 2, figsize=(12,8))
# --- p, modo 0 ---
ax = axes[0]
xx = np.linspace(0, Lx+pml_thickness, 100)
yy = [eval_point_fast(p_exact, bb, x, mesh) for x in xx]
ax.plot(xx, np.real(yy), label="Re(p)", linestyle="-")
yy = [eval_point_fast(p_approx, bb, x, mesh) for x in xx]
ax.plot(xx, np.real(yy), label="Re(p)", linestyle="-.")
ax.set_xlabel("x [m]")
ax.set_ylabel("p(x) [Pa]")
ax.grid(True)


ax = axes[1]
xx = np.linspace(0, Lx+pml_thickness, 100)
yy = [eval_point_fast(v_exact, bb, x, mesh) for x in xx]
ax.plot(xx, np.real(yy), label="Re(v)", linestyle="-")        
yy = [eval_point_fast(v_approx, bb, x, mesh) for x in xx]
ax.plot(xx, np.real(yy), label="Re(v)", linestyle="-.")
ax.set_xlabel("x [m]")
ax.set_ylabel("v(x) ")
ax.grid(True)
fig.suptitle("Sigma {pml_profile} - Modo {eig}, N={N_i}, sigma={sigma_0}".format(pml_profile=pml_profile, eig=eig_number, N_i=N_i, sigma_0=sigma_0))
plt.show()

# %%
from scipy.io import savemat

savemat(
    "results_sigma_optimization_{pml_profile}.mat",
    {
        "pml_thickness": pml_thickness,
        "Lx": Lx,
        "l_inner": l_inner,
        "rho_media1": rho_media_1,
        "rho_media_2": rho_media_2,
        "vel_media_1": vel_media_1,
        "vel_media_2": vel_media_2,
        "sigma_sweep": sigma_sweep,
        "rel err eig": rel_err_eig_sigma_sweep,
        "rel error p": rel_err_p_sigma_sweep,
        "rel error v": rel_err_v_sigma_sweep,
        "rel error total": rel_err_total_sigma_sweep,
        "approx_p": approx_p,
        "approx_v": approx_v,
        "approx_omega": approx_omega,
        "sigma_piecewise_ufl": sigma_piecewise_ufl,
        "target": target,
    }
)
