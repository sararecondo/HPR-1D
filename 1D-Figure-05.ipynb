# %% [markdown]
# Bilayer unit domain. Sigma optimisation

# %%
try:
    import dolfinx
except ImportError:
    # !wget "https://fem-on-colab.github.io/releases/fenicsx-install-release-complex.sh" -O "/tmp/fenicsx-install.sh" && bash "/tmp/fenicsx-install.sh"
    import dolfinx

# %%
import matplotlib.pyplot as plt

try:
	if "science" not in plt.style.available:
		try:
			import scienceplots  # registers styles if installed
		except Exception:
			# Install SciencePlots (registers the 'science' style) and import it
			get_ipython().run_line_magic('pip', 'install -q SciencePlots')
			import scienceplots  # noqa: F401
	plt.style.use(["science", "grid"])
except Exception as e:
	# If anything fails, fall back to a commonly available style
	print("Warning: 'science' style not available. Using 'seaborn' instead. Error:", e)
	plt.style.use("seaborn")

# %%
import matplotlib as mpl
colors_list = [
    "#0C5DA5",  # blue
    "#00B945",  # green
    "#FF9500",  # orange
    "#FF2C00",  # red
    "#845B97",  # purple
    "#474747",  # dark gray
    "#9e9e9e",  # light gray
]

mpl.rcParams["axes.prop_cycle"] = mpl.cycler(color=colors_list)

mpl.rcParams.update({
    # Tamaño físico
    "figure.figsize": (2.9, 2.6),

    # Líneas
    "lines.linewidth": 2.0,
    "lines.markersize": 8,

    # Fuente de títulos, labels y leyendas
    "font.size": 23,
    "axes.labelsize": 23,
    "axes.titlesize": 23,
    "legend.fontsize": 20,

    # Números de los ejes un pelín más pequeños
    "xtick.labelsize": 18,
    "ytick.labelsize": 18,

    # Ejes y ticks
    "axes.linewidth": 1.4,
    "xtick.major.width": 1.4,
    "ytick.major.width": 1.4,

    # PDF limpio
    "pdf.fonttype": 42,
    "ps.fonttype": 42,
})

# %%
# Importing libraries
import matplotlib.pyplot as plt
from matplotlib import ticker
import numpy as np
from mpi4py import MPI
from ufl import (
    inner,
    grad,
    conj,
    TrialFunction,
    TestFunction,
    as_matrix,
    as_vector,
    dot,
    Or,
    Measure,
    conditional,
    SpatialCoordinate,
    dx,
)
from dolfinx.mesh import locate_entities_boundary, create_interval, locate_entities, meshtags
from dolfinx.fem import FunctionSpace, Function, functionspace, Function, dirichletbc, locate_dofs_topological, petsc, form, assemble_matrix, assemble_scalar
import basix
from dolfinx.geometry import bb_tree
from dolfinx import geometry
from petsc4py.PETSc import ScalarType
from slepc4py.SLEPc import EPS

# %% [markdown]
# Domain, PML, refinement and physical configurations

# %%
# Define simulation parameters
# Mesh configuration
h = [0.125/2,   # N=1
      0.125/4,   # N=2
      0.125/8,] # N=3
N = [int(np.log2(0.125 / h_i)) for h_i in h]  # Mesh refinement levels
# Domain configuration
Lx = 1. # fluid domain length (without PML)
l_inner=Lx/2

# Physical configuration
rho_media_1 = 1. # kg/m^3 
vel_media_1 = 2.   # m/s
rho_media_2 = 1. # kg/m^3 
vel_media_2 = 1.   # m/s

# Define the density and velocity functions  
def rho_function(x):    
    return np.where(x[0] > l_inner, rho_media_2,rho_media_1)

def vel_function(x):    
    return np.where(x[0] > l_inner, vel_media_2,vel_media_1)

# PML configuration
pml_thickness = Lx/4

# Solver configuration
requested_eigenvalues_number = 15 # Number of eigenvalues to compute

degree=[2,1]  # Polynomial degree for pressure and velocity

target=[-12.56j, 
        -50.26j] # Shifts for the eigensolvers

pml_profile = "quadratic" # "quadratic"  # 'constant' 'singular'

match pml_profile:
    case 'constant':
        sigma_sweep=sigma_sweep = np.arange(1, 102)  #np.linspace(1., 101., 21) #piecewise
    case 'quadratic':
        sigma_sweep=sigma_sweep = np.arange(50, 151) #np.linspace(1., 201., 21) #quadratic
    case 'singular':
        sigma_sweep=sigma_sweep = np.arange(0.5, 3.1, 0.05) #np.linspace(0.1, 3.1, 21)

# %% [markdown]
# Solver configuration and computing

# %%
def get_configured_problem(mesh, degrees, sigma_x, target):
    # Initialize dictionaries
    dof = {}
    solver_dict={}
    V_dict={}
    Q_dict={}

    # Define finite element spaces
    p_fe_type = basix.ufl.element(family="Lagrange", cell=mesh.basix_cell(), degree=degrees[0])
    v_fe_type = basix.ufl.element(family="DG", cell=mesh.basix_cell(), degree=degrees[1], shape=(mesh.geometry.dim,))
    FE = {"p": p_fe_type, "v": v_fe_type}

    # Create a submesh of PML associated cells
    tdim = mesh.topology.dim

    # Identify the fluid cells
    # fluid_cells = locate_entities(mesh, tdim, lambda x: x[0] <= Lx)

    # Create function spaces for mesh and submesh
    Q = functionspace(mesh,FE["p"])
    V = functionspace(mesh, FE["v"])

    # Dictionaries to store the number of dofs
    dof["p"] = Q.dofmap.index_map.size_global
    dof["v"] = V.dofmap.index_map.size_global

    # Boundary conditions application (for pressure)
    bc = []
    facets = locate_entities_boundary(mesh, 0, lambda x: np.isclose(x[0], 0.0))
    o_boundary_dofs = locate_dofs_topological(Q, 0, facets)  # the dimension is related to mesh entity where dofs are located

    # Setting to zero located dofs related to boundaries
    u_d = Function(Q)
    u_d.x.array[:] = 0.0  # Asign Dirichlet condition value
    bc.append(dirichletbc(u_d, o_boundary_dofs))

    facets = locate_entities_boundary(mesh, 0, lambda x: np.isclose(x[0], Lx+pml_thickness))
    o_boundary_dofs = locate_dofs_topological(Q, 0, facets)  # the dimension is related to mesh entity where dofs are located

    # Define the subdomains using a Python function
    TOL = 1e-6
    def pml_domain(x):
        """Returns True for points in (Lx, Lx + pml_thickness]"""
        return x[0] > Lx - TOL

    # Get topology dimension
    tdim = mesh.topology.dim

    # Locate cells in each subdomain
    pml_cells = locate_entities(mesh, tdim, pml_domain)

    # Create a meshtag to mark the subdomains
    num_cells = mesh.topology.index_map(tdim).size_local
    cell_markers = np.ones(num_cells, dtype=np.int32) # Physical domain tag=1
    cell_markers[pml_cells] = 2       # PML domain tag=2

    cell_tags = meshtags(mesh, tdim, np.arange(num_cells, dtype=np.int32), cell_markers)

    # Now you can use these tags for integration measures
    dx = Measure("dx", domain=mesh, subdomain_data=cell_tags)

    # Setting to zero located dofs related to boundaries
    u_d = Function(Q)
    u_d.x.array[:] = 0.0  # Asign Dirichlet condition value
    bc.append(dirichletbc(u_d, o_boundary_dofs))

    # Interpolates the density and velocity functions
    W = functionspace(mesh, ("DG", 0))
    rho = Function(W)
    rho.interpolate(rho_function)
    c = Function(W)
    c.interpolate(vel_function)

    # Spatial Coordinate is updated for the actual mesh
    x = SpatialCoordinate(mesh)

    # Variation formulation definition
    p = TrialFunction(Q)
    v = TrialFunction(V)
    q = TestFunction(Q)
    w = TestFunction(V)

    # Define the variational forms
    a = form(
        [
            [sigma_x(x) / (rho * c**2) * p * conj(q) * dx(2), -1 * inner(v, grad(q)) * dx],
            [inner(grad(p), w) * dx, sigma_x(x) * rho * inner(v, w) * dx(2)],
        ]
    )
    b = form(
        [
            [1.0 / (rho * c**2) * p * conj(q) * dx, None],
            [None, rho * inner(v, w) * dx],
        ]
    )
    # Assemble matrices
    A = petsc.assemble_matrix_block(a, bcs=bc)
    A.assemble()
    B = petsc.assemble_matrix_block(b, bcs=bc)
    B.assemble()

    # SLEPc solver configuration for linear eigenvalue problem (A x =\lambda x B)
    solver = EPS().create()
    solver.setOperators(-A, B)
    solver.setType("arnoldi")
    solver.setWhichEigenpairs(9)  # TARGET_IMAGINARY = 9, TARGET_MAGNITUDE = 7, TARGET_REAL = 8
    solver.setDimensions(
        requested_eigenvalues_number,
        4 * requested_eigenvalues_number,
        4 * requested_eigenvalues_number,
    )
    solver.setTolerances(1e-16, 100)
    st = solver.getST()
    st.setType("sinvert")  # Applying spectral transformation "shift and invert"
    solver.setTarget(target)
    solver.solve()
    n_eigs_converged_quadratic = solver.getConverged()

    return solver, mesh, Q, V, dof

# %%
def assign_eigenvector_to_functions(vrA, p_h, v_h, dof):
    """
    Reparte o vector eigenvector 'vrA' entre p_h e v_h
    e normaliza no punto 'normalize_at'.
    """

    # --- separar as partes do autovector ---
    p_vals = vrA[:dof["p"]]
    v_vals = vrA[dof["p"]:]

    # asignar
    p_h.x.array[:] = p_vals
    v_h.x.array[:] = v_vals

    return p_h, v_h

# %%
def eigenvector_L2_error_physical(u_num, u_exact, Lx, mesh):
    """
    Erro relativo L2 só no dominio físico [0, Lx] en DOLFINx 0.9.
    Alinea fase/signo antes de medir o erro.
    """

    import numpy as np
    import ufl
    from ufl import inner
    from dolfinx.mesh import locate_entities, meshtags
    from dolfinx.fem import form, assemble_scalar

    
    tdim = mesh.topology.dim
    # Define the subdomains using a Python function
    TOL = 1e-6
    def fluid_domain(x):
        """Returns True for points in [0, Lx]"""
        return np.logical_and(x[0] >= 0, x[0] < Lx + TOL)
    
    # --- 1) Localizar celas físicas ---
    cells_phys = locate_entities(
        mesh, tdim,
        fluid_domain
    )

    if len(cells_phys) == 0:
        raise RuntimeError("Non se detectaron celas na rexión física [0, Lx].")

    # Asignar etiqueta 1
    values = np.full(len(cells_phys), 1, dtype=np.int32)
    mt = meshtags(mesh, tdim, cells_phys, values)

    # Medida restrinxida
    dx_phys = ufl.Measure("dx", domain=mesh, subdomain_data=mt)
    
    # --- 3) Norma L2 do erro no dominio físico ---
    diff = u_num - u_exact

    num = np.sqrt(assemble_scalar(form(inner(diff, diff) * dx_phys(1))))
    den = np.sqrt(assemble_scalar(form(inner(u_exact, u_exact) * dx_phys(1))))

    return num / den

# %%
def get_exact_eigenpair(selected_index, Q, V, x_hat):
    exact_physical_eigs_function= lambda n: vel_media_1 / l_inner * np.arctan(-1j * (vel_media_2 * rho_media_2) / (vel_media_1 * rho_media_1))+ n * np.pi * vel_media_1 / l_inner
    w=exact_physical_eigs_function(selected_index)

    # Función de presión en el primer medio
    p_1 = lambda x: np.sin(w * x / vel_media_1)

    # Valor de p_1 en la interfaz
    p_l_inner = p_1(l_inner)

    # Función de presión en el segundo medio, continua
    p_2 = lambda x: p_l_inner * np.exp(1j * w / vel_media_2 * (x_hat(x, w) - l_inner))

    # Función de presión completa
    p = lambda x: p_1(x[0]) + (x[0] >= l_inner) * (p_2(x[0]) - p_1(x[0]))

    # Velocidad en el primer medio
    def v_1(x):
        return ((-1j/(rho_media_1*vel_media_1)) * np.cos(w * x / vel_media_1))

    # Velocidad en el segundo medio, continua con la interfaz
    def v_2(x):
        return p_1(l_inner)/(rho_media_2*vel_media_2) * np.exp(1j * w / vel_media_2 * (x_hat(x, w) - l_inner))

    # Función de velocidad completa
    v = lambda x: v_1(x[0]) + (x[0] >= l_inner) * (v_2(x[0]) - v_1(x[0]))

    p_ex = Function(Q, name="p_ex")
    p_ex.interpolate(p)

    v_ex = Function(V, name="v_ex")
    v_ex.interpolate(v)

    return [w, p_ex, v_ex]

# %%
def eval_point_fast(u, bb, x, mesh):
    pt = np.array([x, 0.0, 0.0], dtype=np.float64)

    # 1) Buscamos celas candidatas no árbol
    candidates = geometry.compute_collisions_points(bb, pt)

    # 2) Filtramos celas que realmente conteñen o punto
    cell = geometry.compute_colliding_cells(mesh, candidates, pt)

    if len(cell) == 0:
        return np.nan

    # 3) Avaliar a función FEM
    P = np.array([pt])
    C = np.array([cell.array[0]], dtype=np.int32)

    val = u.eval(P, C)
    return val[0]

# %%
def normalize_at_Lx(u, bb, Lx, mesh):
    val_Lx = eval_point_fast(u, bb, Lx, mesh)
    u.x.array[:] /= val_Lx   # normalizando respecto do valor en [Lx, 0, 0]
    return u

# %%
def get_closest_approx_eigenpair(exact_eigenvalue_idx, solver, Q, V, dof, sigma_i, mesh, verbose=False, plot=False):
    """
    Devuelve el autovalor y autovector más cercano a omega_target
    usando distancia compleja |λ - λ_target|, sin usar get_approx_eigenpair.

    Returns
    -------
    lambda_best : complex
    x_best : PETSc.Vec (copia del autovector)
    idx_best : int (índice raw en solver)
    p_h:    Function
    v_h: Function
    """
    p_exact = [None] * 5  # Almacena los autovectores exactos de presión
    v_exact = [None] * 5  # Almacena los autovectores exactos de velocidad
    p_approx = [None] * 5  # Almacena los autovectores exactos de presión
    v_approx = [None] * 5  # Almacena los autovectores exactos de velocidad
    best = None
    best_3 = None

    # Número de modos convergidos
    nconv = solver.getConverged()
    if nconv == 0:
        raise RuntimeError("No hay autovalores convergidos")

    # Vector temporal para extraer Eigenpairs
    vrA, vi = solver.getOperators()[0].getVecs()

    match pml_profile:
        case 'constant':
            x_hat = lambda x, w: x + (x >= Lx) * (1j / w) * sigma_i * (x - Lx)

        case 'quadratic':
            x_hat=lambda x, w: x + (x >= Lx) * (1j / w) * sigma_i* (x - Lx) ** 3/ (3 * pml_thickness**2)

        case 'singular':
            x_hat=lambda x, w: x + (x >= Lx) * (1j / w) * sigma_i *(-np.log((Lx + pml_thickness - x)/pml_thickness))

    [exact_eigenvalue, p_exact, v_exact] =   get_exact_eigenpair(exact_eigenvalue_idx, Q, V, x_hat)

    bb = bb_tree(mesh, mesh.topology.dim)
    for k in range(nconv):
        approx_eigenvalue = solver.getEigenvalue(k) * 1j
        solver.getEigenpair(k, vrA)
        # Vector temporal para extraer Eigenpairs
        p_h = Function(Q, name="p_h")
        v_h = Function(V, name="v_h")
        [p_h, v_h]=assign_eigenvector_to_functions(vrA = vrA, p_h = p_h, v_h = v_h, dof = dof)

        # --- autovalores ---
        err_eig = abs(approx_eigenvalue - exact_eigenvalue) / abs(exact_eigenvalue)

        # --- autovectores ---

        p_h=normalize_at_Lx(p_h, bb, Lx, mesh)
        v_h=normalize_at_Lx(v_h, bb, Lx, mesh)
        p_exact=normalize_at_Lx(p_exact, bb, Lx, mesh)
        v_exact=normalize_at_Lx(v_exact, bb, Lx, mesh)


        # Errores L2 en dominio físico
        err_p = eigenvector_L2_error_physical(p_h, p_exact, Lx, mesh)
        err_v = eigenvector_L2_error_physical(v_h, v_exact, Lx, mesh)

        # Total
        err = (err_eig + err_p + err_v) / 3


        if best is None or err < best[2]:
            best = (approx_eigenvalue, k, err,err_eig, err_p, err_v)

    closest_eig, idx_best, rel_err_total, rel_err_eig_best, rel_err_p_best, rel_err_v_best = best

    # Vector temporal para extraer Eigenpairs
    p_h = Function(Q, name="p_h")
    v_h = Function(V, name="v_h")
    vrA, vi = solver.getOperators()[0].getVecs()
    solver.getEigenpair(idx_best, vrA)
    [p_approx, v_approx]=assign_eigenvector_to_functions(vrA = vrA, p_h = p_h, v_h = v_h, dof = dof)

    if verbose:
        print(f"$\sigma_i={sigma_i}$")
        print(f"$[Closest to \omega={exact_eigenvalue}] idx={idx_best}  \omega={closest_eig}  \epsilon_r={(rel_err_eig_best+rel_err_p_best+rel_err_v_best)/3} \epsilon_r(\omega)={rel_err_eig_best}  \epsilon_r(p)={rel_err_p_best} \epsilon_r(v)={rel_err_v_best}$")


    if plot:
        from dolfinx import geometry

        fig, axes = plt.subplots(1, 2, figsize=(12,8))

        # ============================================================
        #  FILA 1 — AUTOVECTORES p
        # ============================================================

        # --- p, modo 0 ---
        ax = axes[0]


        val_Lx = eval_point_fast(p_approx, bb, Lx, mesh)
        p_approx.x.array[:] /= val_Lx   # normalizando respecto do valor en [Lx, 0, 0]
        val_Lx = eval_point_fast(p_exact, bb, Lx, mesh)
        p_exact.x.array[:] /= val_Lx
        xx = np.linspace(0, Lx+pml_thickness, 2000)
        yy = [eval_point_fast(p_approx, bb, x, mesh) for x in xx]
        ax.plot(xx, np.real(yy), label="Re(p)", linestyle="-.")
        yy = [eval_point_fast(p_exact, bb, x, mesh) for x in xx]
        ax.plot(xx, np.real(yy), label="Re(p)", linestyle="-")
        ax.set_xlabel("x [m]")
        ax.set_ylabel("p(x) [Pa]")
        ax.set_title("Modo {} con sigma singular".format(0))
        ax.grid(True)


        ax = axes[1]
        val_Lx = eval_point_fast(v_approx, bb, Lx, mesh)
        v_approx.x.array[:] /= val_Lx   # normalizando respecto do valor en [Lx, 0, 0]
        val_Lx = eval_point_fast(v_exact, bb, Lx, mesh)
        v_exact.x.array[:] /= val_Lx
        xx = np.linspace(0, Lx+pml_thickness, 2000)
        yy = [eval_point_fast(v_approx, bb, x, mesh) for x in xx]
        ax.plot(xx, np.real(yy), label="Re(v)", linestyle="-.")
        yy = [eval_point_fast(v_exact, bb, x, mesh) for x in xx]
        ax.plot(xx, np.real(yy), label="Re(v)", linestyle="-")
        ax.set_xlabel("x [m]")
        ax.set_ylabel("v(x) ")
        ax.grid(True)

        plt.show()

    return exact_eigenvalue, p_exact, v_exact, closest_eig, p_approx, v_approx, rel_err_eig_best, rel_err_p_best, rel_err_v_best, (rel_err_eig_best + rel_err_p_best + rel_err_v_best) / 3

# %%
# Diccionarios onde gardar os erros para cada refinamento N
rel_err_eig_sigma_sweep = {0: {}, 3: {}}   # erros para modo 0 e 3
rel_err_p_sigma_sweep = {0: {}, 3: {}}   # erros para modo 0 e 3
rel_err_v_sigma_sweep = {0: {}, 3: {}}   # erros para modo 0 e 3
rel_err_total_sigma_sweep = {0: {}, 3: {}}   # erros para modo 0 e 3

approx_omega  = {0: {}, 3: {}}
approx_p      = {0: {}, 3: {}}
approx_v      = {0: {}, 3: {}}
exact_p      = {0: {}, 3: {}}
exact_v      = {0: {}, 3: {}}
exact_omega  = {0: {}, 3: {}}

# Iterar sobre N = 0,1,2 → corresponde a h_i[0], h_i[1], h_i[2]
for N_i, h_i in zip(N, h):

    print(f"\n=== Executando para N = {N_i}, h = {h_i} ===")

    # Inicializar listas baleiras para este N
    rel_err_eig_sigma_sweep[0][N_i] = []
    rel_err_eig_sigma_sweep[3][N_i] = []
    rel_err_p_sigma_sweep[0][N_i] = []
    rel_err_p_sigma_sweep[3][N_i] = []
    rel_err_v_sigma_sweep[0][N_i] = []
    rel_err_v_sigma_sweep[3][N_i] = []
    rel_err_total_sigma_sweep[0][N_i] = []
    rel_err_total_sigma_sweep[3][N_i] = []
    

    approx_omega[0][N_i] = []
    approx_omega[3][N_i] = []

    approx_p[0][N_i] = []
    approx_p[3][N_i] = []
    approx_v[0][N_i] = []
    approx_v[3][N_i] = []

    exact_p[0][N_i] = []
    exact_p[3][N_i] = []

    exact_v[0][N_i] = []
    exact_v[3][N_i] = []

    exact_omega[0][N_i] = []
    exact_omega[3][N_i] = []

    # Crear nova malla para este refinamento
    mesh = create_interval(
        MPI.COMM_WORLD,
        int((Lx + pml_thickness) / h_i),
        [0, Lx + pml_thickness]
    )

    # Percorrer sigma_sweep_piecewise
    for i, sigma_i in enumerate(sigma_sweep):
        match pml_profile:
            case 'constant':
                print(f"Computing for sigma_i = {sigma_i:.2f} (piecewise)")
                sigma_function = lambda x: sigma_i
            case 'quadratic':
                print(f"Computing for sigma_i = {sigma_i:.2f} (quadratic)")
                sigma_function = lambda x: sigma_i * (x[0] - Lx)**2 / (pml_thickness**2)
            case 'singular':
                print(f"Computing for sigma_i = {sigma_i:.2f} (singular)")
                sigma_function = lambda x: sigma_i/(Lx+pml_thickness-x[0])

        sigma_piecewise_ufl = lambda x: sigma_i
        solver_target_0, mesh, Q_, V_, dof_ = get_configured_problem(mesh, degree, sigma_function, target[0])
        solver_target_3, mesh, Q_, V_, dof_ = get_configured_problem(mesh, degree, sigma_function, target[1])
        (eig_ex0, p_ex0, v_ex0, eig0, p0, v0, err0_eig, err0_p, err0_v, total_error) = get_closest_approx_eigenpair(1, solver_target_0, Q_, V_, dof_, sigma_i, mesh,verbose=True, plot=False)
        (eig_ex3, p_ex3, v_ex3, eig3, p3, v3, err3_eig, err3_p, err3_v, total_error) = get_closest_approx_eigenpair(4, solver_target_3, Q_, V_, dof_, sigma_i, mesh,verbose=True, plot=False)

        err0 = (err0_eig + err0_p + err0_v ) /3
        err3 = (err3_eig + err3_p + err3_v) / 3
        # Gardar resultados
        approx_omega[0][N_i].append(eig0)
        approx_omega[3][N_i].append(eig3)

        exact_omega[0][N_i].append(eig_ex0)
        exact_omega[3][N_i].append(eig_ex3)
        approx_p[0][N_i].append(p0)
        approx_p[3][N_i].append(p3)

        approx_v[0][N_i].append(v0)
        approx_v[3][N_i].append(v3)

        exact_p[0][N_i].append(p_ex0)
        exact_p[3][N_i].append(p_ex3)

        exact_v[0][N_i].append(v_ex0)
        exact_v[3][N_i].append(v_ex3)


        rel_err_eig_sigma_sweep[0][N_i].append(err0_eig*100)
        rel_err_eig_sigma_sweep[3][N_i].append(err3_eig*100)

        rel_err_p_sigma_sweep[0][N_i].append(err0_p*100)
        rel_err_p_sigma_sweep[3][N_i].append(err3_p*100)

        rel_err_v_sigma_sweep[0][N_i].append(err0_v*100)
        rel_err_v_sigma_sweep[3][N_i].append(err3_v*100)

        rel_err_total_sigma_sweep[0][N_i].append(err0*100)
        rel_err_total_sigma_sweep[3][N_i].append(err3*100)
# Out:
# === Executando para N = 1, h = 0.0625 ===
# Computing for sigma_i = 50.00 (quadratic)
# $\sigma_i=50$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.578115901949413-2.156583531425752j)  \epsilon_r=(0.015474107732283181+0j) \epsilon_r(\omega)=0.0033161525628099134  \epsilon_r(p)=(0.02130949347256819+0j) \epsilon_r(v)=(0.02179667716147144+0j)$
# $\sigma_i=50$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=4  \omega=(40.99299450462699-23.34822119795225j)  \epsilon_r=(0.7747813574611536+0j) \epsilon_r(\omega)=0.45900688763276276  \epsilon_r(p)=(0.9191495470196354+0j) \epsilon_r(v)=(0.9461876377310626+0j)$
# Computing for sigma_i = 51.00 (quadratic)
# $\sigma_i=51$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.577846393740556-2.160279197485421j)  \epsilon_r=(0.014606427725667507+0j) \epsilon_r(\omega)=0.003032575910640752  \epsilon_r(p)=(0.01949543757891727+0j) \epsilon_r(v)=(0.021291269687444506+0j)$
# $\sigma_i=51$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=4  \omega=(40.864149699682926-24.02444729503586j)  \epsilon_r=(0.7795621057462144+0j) \epsilon_r(\omega)=0.4723542764869726  \epsilon_r(p)=(0.9207379713981784+0j) \epsilon_r(v)=(0.9455940693534926+0j)$
# Computing for sigma_i = 52.00 (quadratic)
# $\sigma_i=52$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.57747092021164-2.163350408891966j)  \epsilon_r=(0.013900553592663298+0j) \epsilon_r(\omega)=0.002794269656091145  \epsilon_r(p)=(0.017977226242517998+0j) \epsilon_r(v)=(0.020930164879380753+0j)$
# $\sigma_i=52$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=4  \omega=(40.73653895953986-24.703853329212688j)  \epsilon_r=(0.7843601696215808+0j) \epsilon_r(\omega)=0.4857689246958874  \epsilon_r(p)=(0.9222786886948704+0j) \epsilon_r(v)=(0.9450328954739847+0j)$
# Computing for sigma_i = 53.00 (quadratic)
# $\sigma_i=53$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.576995571652716-2.165892308159666j)  \epsilon_r=(0.013326713737293053+0j) \epsilon_r(\omega)=0.002593455318698936  \epsilon_r(p)=(0.01670442913937371+0j) \epsilon_r(v)=(0.02068225675380652+0j)$
# $\sigma_i=53$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=4  \omega=(40.610120301184615-25.386359614259753j)  \epsilon_r=(0.789174329139367+0j) \epsilon_r(\omega)=0.49924902377651426  \epsilon_r(p)=(0.9237731312320564+0j) \epsilon_r(v)=(0.9445008324095308+0j)$
# Computing for sigma_i = 54.00 (quadratic)
# $\sigma_i=54$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.576426991616069-2.1679895031796863j)  \epsilon_r=(0.012860270871192212+0j) \epsilon_r(\omega)=0.002423477595760074  \epsilon_r(p)=(0.01563423125847561+0j) \epsilon_r(v)=(0.020523103759340956+0j)$
# $\sigma_i=54$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=4  \omega=(40.48485426518856-26.071889377917735j)  \epsilon_r=(0.7940035144698514+0j) \epsilon_r(\omega)=0.5127928391870502  \epsilon_r(p)=(0.9252227426211903+0j) \epsilon_r(v)=(0.9439949616013138+0j)$
# Computing for sigma_i = 55.00 (quadratic)
# $\sigma_i=55$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.57577211246868-2.1697166155741723j)  \epsilon_r=(0.012481143092262528+0j) \epsilon_r(\omega)=0.0022787611378104165  \epsilon_r(p)=(0.014730872098004106+0j) \epsilon_r(v)=(0.020433796040973062+0j)$
# $\sigma_i=55$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=4  \omega=(40.360703699481355-26.76036862142244j)  \epsilon_r=(0.7988467857725312+0j) \epsilon_r(\omega)=0.5263987061595465  \epsilon_r(p)=(0.9266289634461559+0j) \epsilon_r(v)=(0.9435126877118912+0j)$
# Computing for sigma_i = 56.00 (quadratic)
# $\sigma_i=56$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.575037951191565-2.171138993918132j)  \epsilon_r=(0.012173155496646538+0j) \epsilon_r(\omega)=0.0021547219047084202  \epsilon_r(p)=(0.013964905633397235+0j) \epsilon_r(v)=(0.020399838951833966+0j)$
# $\sigma_i=56$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=4  \omega=(40.23763356568605-27.451725988587246j)  \epsilon_r=(0.8037033160579528+0j) \epsilon_r(\omega)=0.5400650258633627  \epsilon_r(p)=(0.9279932203837872+0j) \epsilon_r(v)=(0.9430517019267085+0j)$
# Computing for sigma_i = 57.00 (quadratic)
# $\sigma_i=57$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.57423145865251-2.1723135175218147j)  \epsilon_r=(0.011923390600873274+0j) \epsilon_r(\omega)=0.0020476498160593125  \epsilon_r(p)=(0.013312361521599612+0j) \epsilon_r(v)=(0.020410160464960896+0j)$
# $\sigma_i=57$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=4  \omega=(40.11561076528046-28.14589264339741j)  \epsilon_r=(0.8085723765283592+0j) \epsilon_r(\omega)=0.5537902618620125  \epsilon_r(p)=(0.9293169179862495+0j) \epsilon_r(v)=(0.9426099497368159+0j)$
# Computing for sigma_i = 58.00 (quadratic)
# $\sigma_i=58$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.57335941381014-2.173289433797572j)  \epsilon_r=(0.011721584671448739+0j) \epsilon_r(\omega)=0.0019545795075701193  \epsilon_r(p)=(0.012753887891769256+0j) \epsilon_r(v)=(0.02045628661500684+0j)$
# $\sigma_i=58$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=4  \omega=(39.99460398320209-28.842802155264184j)  \epsilon_r=(0.8134533239884301+0j) \epsilon_r(\omega)=0.5675729368320943  \epsilon_r(p)=(0.9306014325392782+0j) \epsilon_r(v)=(0.9421856025939178+0j)$
# Computing for sigma_i = 59.00 (quadratic)
# $\sigma_i=59$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.572428354027174-2.1741091878960366j)  \epsilon_r=(0.01155959740198852+0j) \epsilon_r(\omega)=0.0018731630125102428  \epsilon_r(p)=(0.012273940849153326+0j) \epsilon_r(v)=(0.020531688344301996+0j)$
# $\sigma_i=59$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=4  \omega=(39.87458354682954-29.542390391243874j)  \epsilon_r=(0.8183455899960556+0j) \epsilon_r(\omega)=0.5814116295180063  \epsilon_r(p)=(0.9318481075460401+0j) \epsilon_r(v)=(0.9417770329241205+0j)$
# Computing for sigma_i = 60.00 (quadratic)
# $\sigma_i=60$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.571444533293807-2.174809216478108j)  \epsilon_r=(0.011430966365045179+0j) \epsilon_r(\omega)=0.0018015537803524448  \epsilon_r(p)=(0.011860063629174423+0j) \epsilon_r(v)=(0.020631281685608672+0j)$
# $\sigma_i=60$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=4  \omega=(39.75552129853983-30.24459541463419j)  \epsilon_r=(0.8232486714850034+0j) \epsilon_r(\omega)=0.5953049718999355  \epsilon_r(p)=(0.933058250492102+0j) \epsilon_r(v)=(0.9413827920629729+0j)$
# Computing for sigma_i = 61.00 (quadratic)
# $\sigma_i=61$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.57041390125305-2.1754206879932725j)  \epsilon_r=(0.011330546104918128+0j) \epsilon_r(\omega)=0.0017383070774308405  \epsilon_r(p)=(0.011502276340698447+0j) \epsilon_r(v)=(0.0207510548966251+0j)$
# $\sigma_i=61$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=4  \omega=(39.63739048027827-30.949357389455944j)  \epsilon_r=(0.8281621226380786+0j) \epsilon_r(\omega)=0.6092516465558492  \epsilon_r(p)=(0.9342331306204121+0j) \epsilon_r(v)=(0.9410015907379746+0j)$
# Computing for sigma_i = 62.00 (quadratic)
# $\sigma_i=62$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.569342097159502-2.1759701798109585j)  \epsilon_r=(0.011254224476319186+0j) \epsilon_r(\omega)=0.001682298325053212  \epsilon_r(p)=(0.01119257966958699+0j) \epsilon_r(v)=(0.020887795434317357+0j)$
# $\sigma_i=62$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=4  \omega=(39.520165628779324-31.656618490400582j)  \epsilon_r=(0.8330855478282388+0j) \epsilon_r(\omega)=0.6232503842008327  \epsilon_r(p)=(0.9353739775060624+0j) \epsilon_r(v)=(0.9406322817778213+0j)$
# Computing for sigma_i = 63.00 (quadratic)
# $\sigma_i=63$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.56823445412566-2.1764802883456285j)  \epsilon_r=(0.011198705120127725+0j) \epsilon_r(\omega)=0.001632658574150983  \epsilon_r(p)=(0.010924564167039361+0j) \epsilon_r(v)=(0.021038892619192832+0j)$
# $\sigma_i=63$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=5  \omega=(39.40382248025289-32.36632281787368j)  \epsilon_r=(0.8380185954750746+0j) \epsilon_r(\omega)=0.6372999613891007  \epsilon_r(p)=(0.9364819802632295+0j) \epsilon_r(v)=(0.9402738447728938+0j)$
# Computing for sigma_i = 64.00 (quadratic)
# $\sigma_i=64$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.56709601009071-2.176970172331854j)  \epsilon_r=(0.011161343821795629+0j) \epsilon_r(\omega)=0.0015887249824269344  \epsilon_r(p)=(0.010693110354468809+0j) \epsilon_r(v)=(0.02120219612849114+0j)$
# $\sigma_i=64$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=5  \omega=(39.28833788350709-33.07841631781092j)  \epsilon_r=(0.8429609526885085+0j) \epsilon_r(\omega)=0.6513991983657634  \epsilon_r(p)=(0.9375582872516766+0j) \epsilon_r(v)=(0.9399253724480858+0j)$
# Computing for sigma_i = 65.00 (quadratic)
# $\sigma_i=65$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.56593152286739-2.1774560320288665j)  \epsilon_r=(0.011140026983822788+0j) \epsilon_r(\omega)=0.001550003592108723  \epsilon_r(p)=(0.010494162554261813+0j) \epsilon_r(v)=(0.02137591480509783+0j)$
# $\sigma_i=65$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=5  \omega=(39.17368972060069-33.79284670597959j)  \epsilon_r=(0.8479123405913989+0j) \epsilon_r(\omega)=0.6655469570569574  \epsilon_r(p)=(0.9386040061751219+0j) \epsilon_r(v)=(0.9395860585421176+0j)$
# Computing for sigma_i = 66.00 (quadratic)
# $\sigma_i=66$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.564745487361717-2.1779515287221174j)  \epsilon_r=(0.011133081806573703+0j) \epsilon_r(\omega)=0.0015161416326355298  \epsilon_r(p)=(0.010324559685845358+0j) \epsilon_r(v)=(0.021558544101240223+0j)$
# $\sigma_i=66$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=5  \omega=(39.05985683424596-34.509563396497036j)  \epsilon_r=(0.8528725102296574+0j) \epsilon_r(\omega)=0.6797421391878873  \epsilon_r(p)=(0.9396202044883728+0j) \epsilon_r(v)=(0.939255187012712+0j)$
# Computing for sigma_i = 67.00 (quadratic)
# $\sigma_i=67$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.563542153638087-2.1784681497267537j)  \epsilon_r=(0.011139209480947588+0j) \epsilon_r(\omega)=0.00148690677573142  \epsilon_r(p)=(0.010181908064482464+0j) \epsilon_r(v)=(0.021748813602628883+0j)$
# $\sigma_i=67$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=5  \omega=(38.946818961266956-35.22851743432807j)  \epsilon_r=(0.8578412389914357+0j) \epsilon_r(\omega)=0.6939836845195824  \epsilon_r(p)=(0.9406079100409765+0j) \epsilon_r(v)=(0.9389321224137486+0j)$
# Computing for sigma_i = 68.00 (quadratic)
# $\sigma_i=68$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.56232554494098-2.179015524410816j)  \epsilon_r=(0.011157434420358953+0j) \epsilon_r(\omega)=0.0014621711014583467  \epsilon_r(p)=(0.010064483653612726+0j) \epsilon_r(v)=(0.021945648506005788+0j)$
# $\sigma_i=68$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=5  \omega=(38.834556671514214-35.94966143153398j)  \epsilon_r=(0.8628183274684897+0j) \epsilon_r(\omega)=0.7082705691958172  \epsilon_r(p)=(0.9415681119040454+0j) \epsilon_r(v)=(0.9386163013056068+0j)$
# Computing for sigma_i = 69.00 (quadratic)
# $\sigma_i=69$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.561099475108408-2.1796016967234815j)  \epsilon_r=(0.011187064119691338+0j) \epsilon_r(\omega)=0.0014418979051391732  \epsilon_r(p)=(0.009971153712138523+0j) \epsilon_r(v)=(0.022148140741796322+0j)$
# $\sigma_i=69$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=5  \omega=(38.72305131170356-36.67294950705913j)  \epsilon_r=(0.867803596702748+0j) \epsilon_r(\omega)=0.7226018041923961  \epsilon_r(p)=(0.9425017613337255+0j) \epsilon_r(v)=(0.9383072245821221+0j)$
# Computing for sigma_i = 70.00 (quadratic)
# $\sigma_i=70$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.559867565045156-2.180233359460276j)  \epsilon_r=(0.011227655556425936+0j) \epsilon_r(\omega)=0.0014261298463229281  \epsilon_r(p)=(0.009901310063253793+0j) \epsilon_r(v)=(0.02235552675970109+0j)$
# $\sigma_i=70$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=5  \omega=(38.6122849537109-37.398337229863124j)  \epsilon_r=(0.8727968857685129+0j) \epsilon_r(\omega)=0.736976433861813  \epsilon_r(p)=(0.9434097728343246+0j) \epsilon_r(v)=(0.938004450609401+0j)$
# Computing for sigma_i = 71.00 (quadratic)
# $\sigma_i=71$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.558633258087863-2.1809160551169535j)  \epsilon_r=(0.011278985142074236+0j) \epsilon_r(\omega)=0.0014149773029363594  \epsilon_r(p)=(0.009854808182924864+0j) \epsilon_r(v)=(0.022567169940361485+0j)$
# $\sigma_i=71$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=5  \omega=(38.50224034691503-38.125781565195915j)  \epsilon_r=(0.8777980496478893+0j) \epsilon_r(\omega)=0.7513935345664156  \epsilon_r(p)=(0.9442930252930819+0j) \epsilon_r(v)=(0.9377075890841706+0j)$
# Computing for sigma_i = 72.00 (quadratic)
# $\sigma_i=72$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.55739983420368-2.1816543477406865j)  \epsilon_r=(0.01134102012738756+0j) \epsilon_r(\omega)=0.0014086061541211151  \epsilon_r(p)=(0.009831907970400336+0j) \epsilon_r(v)=(0.022782546257641235+0j)$
# $\sigma_i=72$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=5  \omega=(38.39290087421675-38.85524082385226j)  \epsilon_r=(0.882806957362422+0j) \epsilon_r(\omega)=0.7658522133943246  \epsilon_r(p)=(0.9451523631599207+0j) \epsilon_r(v)=(0.9374162955330211+0j)$
# Computing for sigma_i = 73.00 (quadratic)
# $\sigma_i=73$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.556170423038076-2.1824519697230924j)  \epsilon_r=(0.011413890112180115+0j) \epsilon_r(\omega)=0.001407224584607508  \epsilon_r(p)=(0.00983321348168159+0j) \epsilon_r(v)=(0.023001232270251245+0j)$
# $\sigma_i=73$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=16  \omega=(82.33449372767822-20.858081335796758j)  \epsilon_r=(0.8878018385375205+0j) \epsilon_r(\omega)=0.7374409367877662  \epsilon_r(p)=(0.974512871588854+0j) \epsilon_r(v)=(0.9514517072359415+0j)$
# Computing for sigma_i = 74.00 (quadratic)
# $\sigma_i=74$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.55494801587033-2.1833119470253632j)  \epsilon_r=(0.011497857955913269+0j) \epsilon_r(\omega)=0.001411068882831585  \epsilon_r(p)=(0.009859610156037887+0j) \epsilon_r(v)=(0.023222894828870338+0j)$
# $\sigma_i=74$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=5  \omega=(38.1762737896537-40.320043796939714j)  \epsilon_r=(0.892847540915777+0j) \epsilon_r(\omega)=0.7948908802288915  \epsilon_r(p)=(0.9468025079866367+0j) \epsilon_r(v)=(0.936849234531803+0j)$
# Computing for sigma_i = 75.00 (quadratic)
# $\sigma_i=75$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.553735476561874-2.184236705893499j)  \epsilon_r=(0.011593289956921687+0j) \epsilon_r(\omega)=0.001420388576720851  \epsilon_r(p)=(0.009912199204707895+0j) \epsilon_r(v)=(0.02344728208933632+0j)$
# $\sigma_i=75$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=5  \omega=(38.06895576066585-41.055310442102986j)  \epsilon_r=(0.8978790111633081+0j) \epsilon_r(\omega)=0.8094692255277314  \epsilon_r(p)=(0.9475948425706998+0j) \epsilon_r(v)=(0.9365729653914934+0j)$
# Computing for sigma_i = 76.00 (quadratic)
# $\sigma_i=76$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.552535551593726-2.185228163725902j)  \epsilon_r=(0.011700625669384332+0j) \epsilon_r(\omega)=0.0014354315753973242  \epsilon_r(p)=(0.009992229876072302+0j) \epsilon_r(v)=(0.023674215556683368+0j)$
# $\sigma_i=76$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=5  \omega=(37.96228196461003-41.7924377886875j)  \epsilon_r=(0.9029178116673965+0j) \epsilon_r(\omega)=0.8240858614582032  \epsilon_r(p)=(0.9483663202343383+0j) \epsilon_r(v)=(0.9363012533096484+0j)$
# Computing for sigma_i = 77.00 (quadratic)
# $\sigma_i=77$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.551350879291283-2.186287806397992j)  \epsilon_r=(0.011820348137451442+0j) \epsilon_r(\omega)=0.0014564302079995409  \epsilon_r(p)=(0.010101031232636094+0j) \epsilon_r(v)=(0.023903582971718695+0j)$
# $\sigma_i=77$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=5  \omega=(37.8562384002658-42.53139020623714j)  \epsilon_r=(0.9079638605890273+0j) \epsilon_r(\omega)=0.8387400319873718  \epsilon_r(p)=(0.9491176314062758+0j) \epsilon_r(v)=(0.9360339183734346+0j)$
# Computing for sigma_i = 78.00 (quadratic)
# $\sigma_i=78$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.550183998333802-2.1874167540268266j)  \epsilon_r=(0.011952955608302842+0j) \epsilon_r(\omega)=0.0014835891206531593  \epsilon_r(p)=(0.010239945797233928+0j) \epsilon_r(v)=(0.024135331907021437+0j)$
# $\sigma_i=78$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=6  \omega=(37.750811497416876-43.27213315855884j)  \epsilon_r=(0.9130170827842348+0j) \epsilon_r(\omega)=0.8534310055442498  \epsilon_r(p)=(0.949849439278982+0j) \epsilon_r(v)=(0.9357708035294726+0j)$
# Computing for sigma_i = 79.00 (quadratic)
# $\sigma_i=79$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.549037355638301-2.1886158168812315j)  \epsilon_r=(0.012098935903109242+0j) \epsilon_r(\omega)=0.001517075882110384  \epsilon_r(p)=(0.010410267852836051+0j) \epsilon_r(v)=(0.024369463974381295+0j)$
# $\sigma_i=79$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=6  \omega=(37.64598809124564-44.0146331693358j)  \epsilon_r=(0.9180774090376749+0j) \epsilon_r(\omega)=0.8681580741742967  \epsilon_r(p)=(0.9505623809422696+0j) \epsilon_r(v)=(0.9355117719964584+0j)$
# Computing for sigma_i = 80.00 (quadratic)
# $\sigma_i=80$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.547913313700201-2.1898855428937094j)  \epsilon_r=(0.012258744558227477+0j) \epsilon_r(\omega)=0.0015570148729877604  \epsilon_r(p)=(0.010613189233773107+0j) \epsilon_r(v)=(0.024606029567921565+0j)$
# $\sigma_i=80$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=6  \omega=(37.541755398589075-44.75885778952374j)  \epsilon_r=(0.9231447753873236+0j) \epsilon_r(\omega)=0.8829205527403035  \epsilon_r(p)=(0.9512570684842581+0j) \epsilon_r(v)=(0.9352567049374095+0j)$
# Computing for sigma_i = 81.00 (quadratic)
# $\sigma_i=81$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.546814157464393-2.191226258020595j)  \epsilon_r=(0.012432787607413601+0j) \epsilon_r(\omega)=0.001603484651084834  \epsilon_r(p)=(0.010849755090075876+0j) \epsilon_r(v)=(0.02484512308108009+0j)$
# $\sigma_i=81$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=18  \omega=(85.83797109633971-19.272025035464413j)  \epsilon_r=(0.9120766136113932+0j) \epsilon_r(\omega)=0.7842473504163552  \epsilon_r(p)=(0.9840920795890425+0j) \epsilon_r(v)=(0.9678904108287822+0j)$
# Computing for sigma_i = 82.00 (quadratic)
# $\sigma_i=82$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.545742100792443-2.1926381005102002j)  \epsilon_r=(0.012621409504653142+0j) \epsilon_r(\omega)=0.0016565185833020686  \epsilon_r(p)=(0.011120831385859856+0j) \epsilon_r(v)=(0.025086878544797506+0j)$
# $\sigma_i=82$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=18  \omega=(85.7446121014227-19.284013763865083j)  \epsilon_r=(0.911398476194092+0j) \epsilon_r(\omega)=0.7826783059732563  \epsilon_r(p)=(0.9839149586770588+0j) \epsilon_r(v)=(0.9676021639319609+0j)$
# Computing for sigma_i = 83.00 (quadratic)
# $\sigma_i=83$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.54469929258162-2.194121049982179j)  \epsilon_r=(0.012824886254102623+0j) \epsilon_r(\omega)=0.0017161081997104006  \epsilon_r(p)=(0.011427084921594215+0j) \epsilon_r(v)=(0.02533146564100326+0j)$
# $\sigma_i=83$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=18  \omega=(85.65544755664469-19.331709253272017j)  \epsilon_r=(0.9107631665283892+0j) \epsilon_r(\omega)=0.7814946545299069  \epsilon_r(p)=(0.9836609096295809+0j) \epsilon_r(v)=(0.9671339354256802+0j)$
# Computing for sigma_i = 84.00 (quadratic)
# $\sigma_i=84$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.543687822586518-2.1956749520853682j)  \epsilon_r=(0.013043423393860313+0j) \epsilon_r(\omega)=0.0017822085169491156  \epsilon_r(p)=(0.011768975614925058+0j) \epsilon_r(v)=(0.025579086049706764+0j)$
# $\sigma_i=84$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=18  \omega=(85.5692536885777-19.407548380909166j)  \epsilon_r=(0.9101617700860487+0j) \epsilon_r(\omega)=0.7806124234397531  \epsilon_r(p)=(0.9833466001066666+0j) \epsilon_r(v)=(0.9665262867117266+0j)$
# Computing for sigma_i = 85.00 (quadratic)
# $\sigma_i=85$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.54270972698456-2.197299539384853j)  \epsilon_r=(0.01327715814117142+0j) \epsilon_r(\omega)=0.0018547445158176936  \epsilon_r(p)=(0.012146759815136392+0j) \epsilon_r(v)=(0.02582997009256018+0j)$
# $\sigma_i=85$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=17  \omega=(85.48527970716812-19.506180132448762j)  \epsilon_r=(0.9095897613240211+0j) \epsilon_r(\omega)=0.7799751826445971  \epsilon_r(p)=(0.9829845282381426+0j) \epsilon_r(v)=(0.9658095730893237+0j)$
# Computing for sigma_i = 86.00 (quadratic)
# $\sigma_i=86$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.541766993722124-2.198994449030932j)  \epsilon_r=(0.013526164787381102+0j) \epsilon_r(\omega)=0.001933618021652914  \epsilon_r(p)=(0.012560502701580899+0j) \epsilon_r(v)=(0.026084373638909492+0j)$
# $\sigma_i=86$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=17  \omega=(85.40303392793933-19.62365607473173j)  \epsilon_r=(0.909044883606624+0j) \epsilon_r(\omega)=0.779543041537527  \epsilon_r(p)=(0.9825843686352727+0j) \epsilon_r(v)=(0.9650072406470727+0j)$
# Computing for sigma_i = 87.00 (quadratic)
# $\sigma_i=87$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.540861567673229-2.200759237677697j)  \epsilon_r=(0.013790462344866127+0j) \epsilon_r(\omega)=0.002018714383539731  \epsilon_r(p)=(0.013010097407469987+0j) \epsilon_r(v)=(0.026342575243588667+0j)$
# $\sigma_i=87$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=6  \omega=(36.827663416066336-50.014195595367525j)  \epsilon_r=(0.9588089488861616+0j) \epsilon_r(\omega)=0.9871962894109206  \epsilon_r(p)=(0.9556554064801409+0j) \epsilon_r(v)=(0.9335751507674234+0j)$
# Computing for sigma_i = 88.00 (quadratic)
# $\sigma_i=88$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.539995355636792-2.202593394047111j)  \epsilon_r=(0.014070023481834962+0j) \epsilon_r(\omega)=0.0021099085314651165  \epsilon_r(p)=(0.013495288424867231+0j) \epsilon_r(v)=(0.026604873489172533+0j)$
# $\sigma_i=88$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=6  \omega=(36.72773545545455-50.77116266141711j)  \epsilon_r=(0.9639307971930511+0j) \epsilon_r(\omega)=1.0022198884188818  \epsilon_r(p)=(0.9562234306994426+0j) \epsilon_r(v)=(0.933349072460829+0j)$
# Computing for sigma_i = 89.00 (quadratic)
# $\sigma_i=89$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.539170231195069-2.204496349474495j)  \epsilon_r=(0.014364783902785675+0j) \epsilon_r(\omega)=0.0022070701690717703  \epsilon_r(p)=(0.014015697030854044+0j) \epsilon_r(v)=(0.02687158450843121+0j)$
# $\sigma_i=89$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=17  \omega=(85.16371831222739-20.06213947873208j)  \epsilon_r=(0.9075656304494536+0j) \epsilon_r(\omega)=0.7792171381981645  \epsilon_r(p)=(0.981225099598954+0j) \epsilon_r(v)=(0.9622546535512424+0j)$
# Computing for sigma_i = 90.00 (quadratic)
# $\sigma_i=90$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.538388039454006-2.2064674867175085j)  \epsilon_r=(0.014674651505400857+0j) \epsilon_r(\omega)=0.002310068008550244  \epsilon_r(p)=(0.01457084684225382+0j) \epsilon_r(v)=(0.027143039665398508+0j)$
# $\sigma_i=90$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=6  \omega=(36.52933863522631-52.28949561413996j)  \epsilon_r=(0.9741943280202741+0j) \epsilon_r(\omega)=1.0323570668850344  \epsilon_r(p)=(0.957318773248255+0j) \epsilon_r(v)=(0.9329071439275334+0j)$
# Computing for sigma_i = 91.00 (quadratic)
# $\sigma_i=91$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.53765060168157-2.208506147267878j)  \epsilon_r=(0.014999514835214809+0j) \epsilon_r(\omega)=0.002418773063249498  \epsilon_r(p)=(0.015160188065633098+0j) \epsilon_r(v)=(0.027419583376761838+0j)$
# $\sigma_i=91$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=17  \omega=(85.00858626977859-20.407840337840202j)  \epsilon_r=(0.9067085649380171+0j) \epsilon_r(\omega)=0.7796397610683431  \epsilon_r(p)=(0.9802361252402044+0j) \epsilon_r(v)=(0.9602498085055039+0j)$
# Computing for sigma_i = 92.00 (quadratic)
# $\sigma_i=92$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.536959719859293-2.210611637367414j)  \epsilon_r=(0.015339250538803856+0j) \epsilon_r(\omega)=0.002533061082590087  \epsilon_r(p)=(0.01578311947608737+0j) \epsilon_r(v)=(0.02770157105773411+0j)$
# $\sigma_i=92$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=6  \omega=(36.33282200533609-53.81353973598774j)  \epsilon_r=(0.9844840810060422+0j) \epsilon_r(\omega)=1.062611015033092  \epsilon_r(p)=(0.9583625289123257+0j) \epsilon_r(v)=(0.9324786990727093+0j)$
# Computing for sigma_i = 93.00 (quadratic)
# $\sigma_i=93$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.536317181159292-2.212783232896551j)  \epsilon_r=(0.01569372966914436+0j) \epsilon_r(\omega)=0.0026528142497771853  \epsilon_r(p)=(0.01643900757837336+0j) \epsilon_r(v)=(0.027989367179282545+0j)$
# $\sigma_i=93$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=6  \omega=(36.2352450393756-54.577648531658355j)  \epsilon_r=(0.989638712326415+0j) \epsilon_r(\omega)=1.0777806355790551  \epsilon_r(p)=(0.9588660145400961+0j) \epsilon_r(v)=(0.9322694868600939+0j)$
# Computing for sigma_i = 94.00 (quadratic)
# $\sigma_i=94$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.535724762358514-2.2150201832776157j)  \epsilon_r=(0.016062822814452888+0j) \epsilon_r(\omega)=0.002777922274187705  \epsilon_r(p)=(0.01712720274344957+0j) \epsilon_r(v)=(0.028283343425721388+0j)$
# $\sigma_i=94$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=6  \omega=(36.138110033709765-55.34312060108244j)  \epsilon_r=(0.9947998075160502+0j) \epsilon_r(\omega)=1.0929781084607793  \epsilon_r(p)=(0.9593577193378146+0j) \epsilon_r(v)=(0.9320635947495571+0j)$
# Computing for sigma_i = 95.00 (quadratic)
# $\sigma_i=95$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.535184234199171-2.2173217145110216j)  \epsilon_r=(0.01644640410500025+0j) \epsilon_r(\omega)=0.0029082830059121347  \epsilon_r(p)=(0.01784705236495044+0j) \epsilon_r(v)=(0.02858387694413818+0j)$
# $\sigma_i=95$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=6  \omega=(36.04140800792017-56.10993589321041j)  \epsilon_r=(0.9999673384623828+0j) \epsilon_r(\omega)=1.1082030180502773  \epsilon_r(p)=(0.9598379875976095+0j) \epsilon_r(v)=(0.9318610097392618+0j)$
# Computing for sigma_i = 96.00 (quadratic)
# $\sigma_i=96$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.534697365705608-2.2196870314416794j)  \epsilon_r=(0.01684435420323935+0j) \epsilon_r(\omega)=0.003043802686260252  \epsilon_r(p)=(0.018597911245107103+0j) \epsilon_r(v)=(0.028891348678350706+0j)$
# $\sigma_i=96$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=6  \omega=(35.945130152522395-56.87807502596412j)  \epsilon_r=(1.0051412780779105+0j) \epsilon_r(\omega)=1.123454962939572  \epsilon_r(p)=(0.9603071513285255+0j) \epsilon_r(v)=(0.9316617199656347+0j)$
# Computing for sigma_i = 97.00 (quadratic)
# $\sigma_i=97$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.534265928463256-2.222115319336844j)  \epsilon_r=(0.01725656241018768+0j) \epsilon_r(\omega)=0.0031843959309237747  \epsilon_r(p)=(0.019379149517038098+0j) \epsilon_r(v)=(0.02920614178260117+0j)$
# $\sigma_i=97$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=6  \omega=(35.849267822871774-57.647519270256936j)  \epsilon_r=(1.0103216002391604+0j) \epsilon_r(\omega)=1.1387335555675218  \epsilon_r(p)=(0.9607655307774815+0j) \epsilon_r(v)=(0.9314657143724785+0j)$
# Computing for sigma_i = 98.00 (quadratic)
# $\sigma_i=98$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.533891700867864-2.2246057448412335j)  \epsilon_r=(0.017682928028341795+0j) \epsilon_r(\omega)=0.0033299855241773367  \epsilon_r(p)=(0.020190158450077215+0j) \epsilon_r(v)=(0.029528640110770832+0j)$
# $\sigma_i=98$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=6  \omega=(35.7538125336296-58.41825053443213j)  \epsilon_r=(1.0155082797199273+0j) \epsilon_r(\omega)=1.1540384218575825  \epsilon_r(p)=(0.9612134349260477+0j) \epsilon_r(v)=(0.9312729823761514+0j)$
# Computing for sigma_i = 99.00 (quadratic)
# $\sigma_i=99$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.533576472349925-2.2271574563612035j)  \epsilon_r=(0.01812336111767438+0j) \epsilon_r(\omega)=0.003480502085773886  \epsilon_r(p)=(0.021030354488788067+0j) \epsilon_r(v)=(0.029859226778461197+0j)$
# $\sigma_i=99$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.34381950459661-2.529869555305496j)  \epsilon_r=(1.019736550123935+0j) \epsilon_r(\omega)=0.39911950792159123  \epsilon_r(p)=(1.2184399591408825+0j) \epsilon_r(v)=(1.4416501833093314+0j)$
# Computing for sigma_i = 100.00 (quadratic)
# $\sigma_i=100$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.533322047580151-2.229769583920032j)  \epsilon_r=(0.018577782769307195+0j) \epsilon_r(\omega)=0.003635883657478526  \epsilon_r(p)=(0.021899181854636962+0j) \epsilon_r(v)=(0.030198282795806105+0j)$
# $\sigma_i=100$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.34995480918684-2.5292243200366973j)  \epsilon_r=(1.0200640132944652+0j) \epsilon_r(\omega)=0.3992412205910764  \epsilon_r(p)=(1.2186293348259816+0j) \epsilon_r(v)=(1.442321484466338+0j)$
# Computing for sigma_i = 101.00 (quadratic)
# $\sigma_i=101$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.53313025065827-2.2324412385148227j)  \epsilon_r=(0.01904612500643801+0j) \epsilon_r(\omega)=0.0037960752440495  \epsilon_r(p)=(0.022796114005207428+0j) \epsilon_r(v)=(0.03054618577005711+0j)$
# $\sigma_i=101$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.35599802321846-2.5286334909556127j)  \epsilon_r=(1.0203830255227697+0j) \epsilon_r(\omega)=0.39936112155904274  \epsilon_r(p)=(1.2188122026888972+0j) \epsilon_r(v)=(1.4429757523203697+0j)$
# Computing for sigma_i = 102.00 (quadratic)
# $\sigma_i=102$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.533002929290276-2.235171510997332j)  \epsilon_r=(0.019528330404440575+0j) \epsilon_r(\omega)=0.003961028333436098  \epsilon_r(p)=(0.02372065420349399+0j) \epsilon_r(v)=(0.03090330867639163+0j)$
# $\sigma_i=102$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.3619518760623-2.5280968251909384j)  \epsilon_r=(1.020693648245564+0j) \epsilon_r(\omega)=0.39947926487095037  \epsilon_r(p)=(1.2189885860468443+0j) \epsilon_r(v)=(1.4436130938188971+0j)$
# Computing for sigma_i = 103.00 (quadratic)
# $\sigma_i=103$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.532941958954057-2.2379594704935006j)  \epsilon_r=(0.020024351506767464+0j) \epsilon_r(\omega)=0.004130700413519889  \epsilon_r(p)=(0.024672335410135506+0j) \epsilon_r(v)=(0.03127001869664701+0j)$
# $\sigma_i=103$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.36781911619236-2.527614091759041j)  \epsilon_r=(1.0209959460197853+0j) \epsilon_r(\omega)=0.39959570496585434  \epsilon_r(p)=(1.2191585099346018+0j) \epsilon_r(v)=(1.4442336231589001+0j)$
# Computing for sigma_i = 104.00 (quadratic)
# $\sigma_i=104$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.532949247054782-2.2408041623670054j)  \epsilon_r=(0.020534150097115223+0j) \epsilon_r(\omega)=0.004305054496504432  \epsilon_r(p)=(0.025650719670203347+0j) \epsilon_r(v)=(0.031646676124637896+0j)$
# $\sigma_i=104$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.37360250532599-2.5271850624866268j)  \epsilon_r=(1.0212899871060985+0j) \epsilon_r(\omega)=0.39971049655678664  \epsilon_r(p)=(1.2193220019701172+0j) \epsilon_r(v)=(1.4448374627913922+0j)$
# Computing for sigma_i = 105.00 (quadratic)
# $\sigma_i=105$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.53302673706899-2.2437046057288055j)  \epsilon_r=(0.021057696375771626+0j) \epsilon_r(\omega)=0.004484058657849471  \epsilon_r(p)=(0.026655397132429308+0j) \epsilon_r(v)=(0.0320336333370361+0j)$
# $\sigma_i=105$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.37930481277624-2.526809504286787j)  \epsilon_r=(1.0215758439298537+0j) \epsilon_r(\omega)=0.39982369451583083  \epsilon_r(p)=(1.219479093069592+0j) \epsilon_r(v)=(1.4454247442041386+0j)$
# Computing for sigma_i = 106.00 (quadratic)
# $\sigma_i=106$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.53317641267428-2.2466597904847485j)  \epsilon_r=(0.021594968076043417+0j) \epsilon_r(\omega)=0.004667685593117458  \epsilon_r(p)=(0.0276859848070345+0j) \epsilon_r(v)=(0.0324312338279783+0j)$
# $\sigma_i=106$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.38492881005185-2.5264871726409313j)  \epsilon_r=(1.0218535934339972+0j) \epsilon_r(\omega)=0.3999353537645335  \epsilon_r(p)=(1.219629818028988+0j) \epsilon_r(v)=(1.44599560850847+0j)$
# Computing for sigma_i = 107.00 (quadratic)
# $\sigma_i=107$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.533400301860077-2.2496686739101706j)  \epsilon_r=(0.02214594954735823+0j) \epsilon_r(\omega)=0.004855912193803913  \epsilon_r(p)=(0.02874212514319866+0j) \epsilon_r(v)=(0.032839811305072124+0j)$
# $\sigma_i=107$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.39047726573341-2.526217806151479j)  \epsilon_r=(1.0221233173374293+0j) \epsilon_r(\omega)=0.40004552917016356  \epsilon_r(p)=(1.2197742159875584+0j) \epsilon_r(v)=(1.4465502068545668+0j)$
# Computing for sigma_i = 108.00 (quadratic)
# $\sigma_i=108$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.533700481010849-2.2527301767333996j)  \epsilon_r=(0.02271063082372004+0j) \epsilon_r(\omega)=0.005048719141447551  \epsilon_r(p)=(0.029823484485841115+0j) \epsilon_r(v)=(0.03325968884387146+0j)$
# $\sigma_i=108$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.39595294064647-2.526001122038402j)  \epsilon_r=(1.0223851023113468+0j) \epsilon_r(\omega)=0.40015427544818044  \epsilon_r(p)=(1.2199123307882394+0j) \epsilon_r(v)=(1.447088700697621+0j)$
# Computing for sigma_i = 109.00 (quadratic)
# $\sigma_i=109$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.534079078953363-2.255843178704848j)  \epsilon_r=(0.02328900668911534+0j) \epsilon_r(\omega)=0.0052460905179219424  \epsilon_r(p)=(0.03092975145309139+0j) \epsilon_r(v)=(0.03369117809633268+0j)$
# $\sigma_i=109$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.40135858333782-2.5258368124717023j)  \epsilon_r=(1.0226390400842738+0j) \epsilon_r(\omega)=0.4002616470709947  \epsilon_r(p)=(1.2200442112472316+0j) \epsilon_r(v)=(1.4476112619345949+0j)$
# Computing for sigma_i = 110.00 (quadratic)
# $\sigma_i=110$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.534538280951686-2.259006513622919j)  \epsilon_r=(0.02388107574685378+0j) \epsilon_r(\omega)=0.005448013429079697  \epsilon_r(p)=(0.032060635262896854+0j) \epsilon_r(v)=(0.03413457854858479+0j)$
# $\sigma_i=110$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.40669692586827-2.525724541634526j)  \epsilon_r=(1.0228852274858908+0j) \epsilon_r(\omega)=0.40036769818324247  \epsilon_r(p)=(1.2201699113447357+0j) \epsilon_r(v)=(1.4481180729296945+0j)$
# Computing for sigma_i = 111.00 (quadratic)
# $\sigma_i=111$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.535080332633406-2.2622189637833907j)  \epsilon_r=(0.024486839494973756+0j) \epsilon_r(\omega)=0.0056544776381368764  \epsilon_r(p)=(0.03321586402520386+0j) \epsilon_r(v)=(0.03459017682158053+0j)$
# $\sigma_i=111$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.41197067991948-2.5256639434318733j)  \epsilon_r=(1.0231237664380997+0j) \epsilon_r(\omega)=0.40047248252349743  \epsilon_r(p)=(1.220289490346994+0j) \epsilon_r(v)=(1.4486093264438078+0j)$
# Computing for sigma_i = 112.00 (quadratic)
# $\sigma_i=112$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.535707543822781-2.2654792538126847j)  \epsilon_r=(0.02510630140643448+0j) \epsilon_r(\omega)=0.00586547520474374  \epsilon_r(p)=(0.034395183007271575+0j) \epsilon_r(v)=(0.03505824600728813+0j)$
# $\sigma_i=112$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.4171825332105-2.5256546197540652j)  \epsilon_r=(1.0233547639021106+0j) \epsilon_r(\omega)=0.4005760533522974  \epsilon_r(p)=(1.2204030128696621+0j) \epsilon_r(v)=(1.4490852254843722+0j)$
# Computing for sigma_i = 113.00 (quadratic)
# $\sigma_i=113$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.536422292252542-2.268786043841347j)  \epsilon_r=(0.025739466009908292+0j) \epsilon_r(\omega)=0.0060810001253078436  \epsilon_r(p)=(0.03559835287266077+0j) \epsilon_r(v)=(0.035539045031756276+0j)$
# $\sigma_i=113$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.42233514622217-2.52569613923058j)  \epsilon_r=(1.0235783317876392+0j) \epsilon_r(\omega)=0.40067846338642793  \epsilon_r(p)=(1.2205105488901606+0j) \epsilon_r(v)=(1.4495459830863295+0j)$
# Computing for sigma_i = 114.00 (quadratic)
# $\sigma_i=114$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.53722702711783-2.2721379219683113j)  \epsilon_r=(0.026386337964462037+0j) \epsilon_r(\omega)=0.0063010479698279885  \epsilon_r(p)=(0.03682514788847506+0j) \epsilon_r(v)=(0.03603281803508306+0j)$
# $\sigma_i=114$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.42743114921696-2.5257880364009715j)  \epsilon_r=(1.0237945868311586+0j) \epsilon_r(\omega)=0.40077976473918997  \epsilon_r(p)=(1.2206121737169946+0j) \epsilon_r(v)=(1.4499918220372916+0j)$
# Computing for sigma_i = 115.00 (quadratic)
# $\sigma_i=115$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.538124272428183-2.2755333959625283j)  \epsilon_r=(0.027046921119510153+0j) \epsilon_r(\omega)=0.006525615510264605  \epsilon_r(p)=(0.038075354091108106+0j) \epsilon_r(v)=(0.036539793757157754+0j)$
# $\sigma_i=115$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.43247313954566-2.5259298112496507j)  \epsilon_r=(1.0240036504485124+0j) \epsilon_r(\omega)=0.4008800088664653  \epsilon_r(p)=(1.2207079679226722+0j) \epsilon_r(v)=(1.4504229745563997+0j)$
# Computing for sigma_i = 116.00 (quadratic)
# $\sigma_i=116$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.539116630104546-2.2789708841426553j)  \epsilon_r=(0.027721217549212182+0j) \epsilon_r(\omega)=0.0067547003351078735  \epsilon_r(p)=(0.039348767396234614+0j) \epsilon_r(v)=(0.03706018491629406+0j)$
# $\sigma_i=116$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.43746367922955-2.5261209290451943j)  \epsilon_r=(1.024205648567051+0j) \epsilon_r(\omega)=0.4009792465183301  \epsilon_r(p)=(1.2207980172462307+0j) \epsilon_r(v)=(1.4508396819365923+0j)$
# Computing for sigma_i = 117.00 (quadratic)
# $\sigma_i=117$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.540206782755936-2.2824487053727864j)  \epsilon_r=(0.02840922654940885+0j) \epsilon_r(\omega)=0.006988300444688668  \epsilon_r(p)=(0.040645191636424265+0j) \epsilon_r(v)=(0.037594187567113614+0j)$
# $\sigma_i=117$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.44240529279882-2.526360820446886j)  \epsilon_r=(1.0244007114411382+0j) \epsilon_r(\omega)=0.4010775276958292  \epsilon_r(p)=(1.2208824124702229+0j) \epsilon_r(v)=(1.451242194157363+0j)$
# Computing for sigma_i = 118.00 (quadratic)
# $\sigma_i=118$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.541397496058055-2.285965068107342j)  \epsilon_r=(0.02911094358334761+0j) \epsilon_r(\omega)=0.007226413821396691  \epsilon_r(p)=(0.041964436506335905+0j) \epsilon_r(v)=(0.038141980422310234+0j)$
# $\sigma_i=118$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.44730046538477-2.526648881827167j)  \epsilon_r=(1.024588973455259+0j) \epsilon_r(\omega)=0.40117490161283936  \epsilon_r(p)=(1.220961249277206+0j) \epsilon_r(v)=(1.4516307694757316+0j)$
# Computing for sigma_i = 119.00 (quadratic)
# $\sigma_i=119$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.542691620642442-2.2895180584156596j)  \epsilon_r=(0.029826359161147238+0j) \epsilon_r(\omega)=0.0074690379686739635  \epsilon_r(p)=(0.04330631539312391+0j) \epsilon_r(v)=(0.03870372412164384+0j)$
# $\sigma_i=119$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.45215164103564-2.5269844757786495j)  \epsilon_r=(1.024770572918292+0j) \epsilon_r(\omega)=0.40127141666241933  \epsilon_r(p)=(1.2210346280903441+0j) \epsilon_r(v)=(1.452005674002113+0j)$
# Computing for sigma_i = 120.00 (quadratic)
# $\sigma_i=120$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.54409209338463-2.293105626914821j)  \epsilon_r=(0.030555457636829046+0j) \epsilon_r(\omega)=0.007716169412392354  \epsilon_r(p)=(0.04467064306757458+0j) \epsilon_r(v)=(0.03927956043052021+0j)$
# $\sigma_i=120$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.45696122125773-2.5273669317756555j)  \epsilon_r=(1.0249456518507527+0j) \epsilon_r(\omega)=0.4013671203876671  \epsilon_r(p)=(1.22110265390001+0j) \epsilon_r(v)=(1.4523671812645813+0j)$
# Computing for sigma_i = 121.00 (quadratic)
# $\sigma_i=121$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.545601937962928-2.29672557453915j)  \epsilon_r=(0.03129821590547065+0j) \epsilon_r(\omega)=0.007967803157844532  \epsilon_r(p)=(0.04605723320946156+0j) \epsilon_r(v)=(0.03986961134910586+0j)$
# $\sigma_i=121$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.46173156375554-2.5277955469556304j)  \epsilon_r=(1.0251143557687379+0j) \epsilon_r(\omega)=0.40146205945655605  \epsilon_r(p)=(1.2211654360814221+0j) \epsilon_r(v)=(1.4527155717682354+0j)$
# Computing for sigma_i = 122.00 (quadratic)
# $\sigma_i=122$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.54722426453443-2.300375537076098j)  \epsilon_r=(0.03205460198198641+0j) \epsilon_r(\omega)=0.008223932095270574  \epsilon_r(p)=(0.0474658957386627+0j) \epsilon_r(v)=(0.040473978112025966+0j)$
# $\sigma_i=122$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.46646498135635-2.528269587001008j)  \epsilon_r=(1.0252768334658442+0j) \epsilon_r(\omega)=0.4015562796404528  \epsilon_r(p)=(1.2212230882048216+0j) \epsilon_r(v)=(1.4530511325522582+0j)$
# Computing for sigma_i = 123.00 (quadratic)
# $\sigma_i=123$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.548962268349952-2.3040529684019844j)  \epsilon_r=(0.03282457344195723+0j) \epsilon_r(\omega)=0.00848454634645573  \epsilon_r(p)=(0.04889643392181108+0j) \epsilon_r(v)=(0.04109274005760489+0j)$
# $\sigma_i=123$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.47116374111718-2.5287882870967486j)  \epsilon_r=(1.0254332367954992+0j) \epsilon_r(\omega)=0.4016498257962711  \epsilon_r(p)=(1.2212757278411992+0j) \epsilon_r(v)=(1.4533741567490275+0j)$
# Computing for sigma_i = 124.00 (quadratic)
# $\sigma_i=124$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.550819227101327-2.307755122359563j)  \epsilon_r=(0.033608075704228385+0j) \epsilon_r(\omega)=0.008749632544697936  \epsilon_r(p)=(0.05034864122302789+0j) \epsilon_r(v)=(0.04172595334495934+0j)$
# $\sigma_i=124$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.47583006358236-2.529350852947295j)  \epsilon_r=(1.0255837204545988+0j) \epsilon_r(\omega)=0.40174274185162817  \epsilon_r(p)=(1.2213234763649243+0j) \epsilon_r(v)=(1.4536849431472443+0j)$
# Computing for sigma_i = 125.00 (quadratic)
# $\sigma_i=125$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.552798496760142-2.311479033229616j)  \epsilon_r=(0.03440504013412807+0j) \epsilon_r(\omega)=0.009019173040098786  \epsilon_r(p)=(0.051822297865651575+0j) \epsilon_r(v)=(0.04237364949663384+0j)$
# $\sigma_i=125$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.48046612219467-2.529956461834558j)  \epsilon_r=(1.0257284417702215+0j) \epsilon_r(\omega)=0.40183507079305447  \epsilon_r(p)=(1.2213664587555402+0j) \epsilon_r(v)=(1.45398379576207+0j)$
# Computing for sigma_i = 126.00 (quadratic)
# $\sigma_i=126$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.554903505630891-2.315221494768761j)  \epsilon_r=(0.035215381946509194+0j) \epsilon_r(\omega)=0.009293145022172468  \epsilon_r(p)=(0.05331716707235655+0j) \epsilon_r(v)=(0.04303583374499855+0j)$
# $\sigma_i=126$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.48507404283481-2.53060426370332j)  \epsilon_r=(1.0258675604906085+0j) \epsilon_r(\omega)=0.4019268546567578  \epsilon_r(p)=(1.2214048034003062+0j) \epsilon_r(v)=(1.454271023414761+0j)$
# Computing for sigma_i = 127.00 (quadratic)
# $\sigma_i=127$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.557137746304887-2.3189790378065527j)  \epsilon_r=(0.03603899788680656+0j) \epsilon_r(\omega)=0.009571519551469952  \epsilon_r(p)=(0.05483299094917296+0j) \epsilon_r(v)=(0.04371248315977678+0j)$
# $\sigma_i=127$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=9  \omega=(70.48965590348655-2.5312933822650048j)  \epsilon_r=(1.026001238580502+0j) \epsilon_r(\omega)=0.4020181345218827  \epsilon_r(p)=(1.2214386418978156+0j) \epsilon_r(v)=(1.4545469393218073+0j)$
# Computing for sigma_i = 128.00 (quadratic)
# $\sigma_i=128$
# ...
# $\sigma_i=125$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.266508966307086-2.196719130551127j)  \epsilon_r=(0.008848006866909706+0j) \epsilon_r(\omega)=2.2741447686914366e-05  \epsilon_r(p)=(0.004044115302268852+0j) \epsilon_r(v)=(0.022477163850773352+0j)$
# Computing for sigma_i = 126.00 (quadratic)
# $\sigma_i=126$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.566489407857329-2.1972015681354913j)  \epsilon_r=(0.0003014103525114368+0j) \epsilon_r(\omega)=9.485079648859563e-06  \epsilon_r(p)=(5.580506548702046e-05+0j) \epsilon_r(v)=(0.0008389409123984304+0j)$
# $\sigma_i=126$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.266509704562445-2.1967192451029516j)  \epsilon_r=(0.008847853730241582+0j) \epsilon_r(\omega)=2.2753607368032608e-05  \epsilon_r(p)=(0.0040437710358116+0j) \epsilon_r(v)=(0.022477036547545112+0j)$
# Computing for sigma_i = 127.00 (quadratic)
# $\sigma_i=127$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.56649084521381-2.197201906536775j)  \epsilon_r=(0.00030161122471597334+0j) \epsilon_r(\omega)=9.590768895123133e-06  \epsilon_r(p)=(5.642879518162715e-05+0j) \epsilon_r(v)=(0.0008388141100711697+0j)$
# $\sigma_i=127$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.266510443138344-2.1967193571780035j)  \epsilon_r=(0.008847700595272151+0j) \epsilon_r(\omega)=2.2765797669673362e-05  \epsilon_r(p)=(0.004043426975850222+0j) \epsilon_r(v)=(0.02247690901229656+0j)$
# Computing for sigma_i = 128.00 (quadratic)
# $\sigma_i=128$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.566492284905138-2.197202248933427j)  \epsilon_r=(0.00030181327937018893+0j) \epsilon_r(\omega)=9.696811434856202e-06  \epsilon_r(p)=(5.705509547674901e-05+0j) \epsilon_r(v)=(0.0008386879311989615+0j)$
# $\sigma_i=128$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.2665111820086-2.196719467238301j)  \epsilon_r=(0.00884754745530752+0j) \epsilon_r(\omega)=2.2778014026160615e-05  \epsilon_r(p)=(0.004043083069408979+0j) \epsilon_r(v)=(0.02247678128248742+0j)$
# Computing for sigma_i = 129.00 (quadratic)
# $\sigma_i=129$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.566493726886039-2.197202595680523j)  \epsilon_r=(0.0003020165062214639+0j) \epsilon_r(\omega)=9.803196310503485e-06  \epsilon_r(p)=(5.768387658028098e-05+0j) \epsilon_r(v)=(0.0008385624457736072+0j)$
# $\sigma_i=129$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.266511921150126-2.196719575677004j)  \epsilon_r=(0.00884739430479036+0j) \epsilon_r(\omega)=2.2790252541956806e-05  \epsilon_r(p)=(0.004042739271746483+0j) \epsilon_r(v)=(0.02247665339008264+0j)$
# Computing for sigma_i = 130.00 (quadratic)
# $\sigma_i=130$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.5664951711121-2.197202947073377j)  \epsilon_r=(0.0003022208959948371+0j) \epsilon_r(\omega)=9.909914053553575e-06  \epsilon_r(p)=(5.831506067297558e-05+0j) \epsilon_r(v)=(0.0008384377132579822+0j)$
# $\sigma_i=130$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.266512660538496-2.1967196828277626j)  \epsilon_r=(0.008847241140006241+0j) \epsilon_r(\omega)=2.280250982831992e-05  \epsilon_r(p)=(0.00404239554707179+0j) \epsilon_r(v)=(0.02247652536311862+0j)$
# Computing for sigma_i = 131.00 (quadratic)
# $\sigma_i=131$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.566496617540977-2.1972033033561034j)  \epsilon_r=(0.0003024264403438285+0j) \epsilon_r(\omega)=1.0016956537880511e-05  \epsilon_r(p)=(5.8948580565397594e-05+0j) \epsilon_r(v)=(0.0008383137839282074+0j)$
# $\sigma_i=131$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.26651340014998-2.196719788975232j)  \epsilon_r=(0.008847087958380464+0j) \epsilon_r(\omega)=2.2814782945839725e-05  \epsilon_r(p)=(0.004042051866144994+0j) \epsilon_r(v)=(0.02247639722605056+0j)$
# Computing for sigma_i = 132.00 (quadratic)
# $\sigma_i=132$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.566498066132434-2.197203664728428j)  \epsilon_r=(0.00030263313167478296+0j) \epsilon_r(\omega)=1.012431678927736e-05  \epsilon_r(p)=(5.958437819696338e-05+0j) \epsilon_r(v)=(0.0008381907000381082+0j)$
# $\sigma_i=132$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.26651413996138-2.196719894361943j)  \epsilon_r=(0.008846934758283773+0j) \epsilon_r(\omega)=2.282706933950599e-05  \epsilon_r(p)=(0.004041708205244376+0j) \epsilon_r(v)=(0.02247626900026744+0j)$
# Computing for sigma_i = 133.00 (quadratic)
# $\sigma_i=133$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.566499516845973-2.1972040313543544j)  \epsilon_r=(0.000302840962725985+0j) \epsilon_r(\omega)=1.0231988604115353e-05  \epsilon_r(p)=(6.022240192965474e-05+0j) \epsilon_r(v)=(0.000838068497644185+0j)$
# $\sigma_i=133$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.266514879949874-2.19671999919528j)  \epsilon_r=(0.008846781538990964+0j) \epsilon_r(\omega)=2.2839366774102276e-05  \epsilon_r(p)=(0.004041364545634159+0j) \epsilon_r(v)=(0.022476140704564634+0j)$
# Computing for sigma_i = 134.00 (quadratic)
# $\sigma_i=134$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.566500969644586-2.1972044033653555j)  \epsilon_r=(0.0003030499269466864+0j) \epsilon_r(\omega)=1.0339966728634785e-05  \epsilon_r(p)=(6.086260744747661e-05+0j) \epsilon_r(v)=(0.0008379472066639478+0j)$
# $\sigma_i=134$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.26651562009161-2.1967201036514625j)  \epsilon_r=(0.008846628300751676+0j) \epsilon_r(\omega)=2.2851673272822922e-05  \epsilon_r(p)=(0.004041020873173347+0j) \epsilon_r(v)=(0.022476012355808858+0j)$
# Computing for sigma_i = 135.00 (quadratic)
# $\sigma_i=135$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.566502424490503-2.1972047808679274j)  \epsilon_r=(0.0003032600178784568+0j) \epsilon_r(\omega)=1.0448246377129594e-05  \epsilon_r(p)=(6.150495450746496e-05+0j) \epsilon_r(v)=(0.000837826852750776+0j)$
# $\sigma_i=135$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.26651636036433-2.196720207881644j)  \epsilon_r=(0.008846475044155564+0j) \epsilon_r(\omega)=2.286398711002485e-05  \epsilon_r(p)=(0.00404067717663175+0j) \epsilon_r(v)=(0.022475883968724922+0j)$
# Computing for sigma_i = 136.00 (quadratic)
# $\sigma_i=136$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.566503881347732-2.1972051639469043j)  \epsilon_r=(0.0003034712294426649+0j) \epsilon_r(\omega)=1.0556823342157509e-05  \epsilon_r(p)=(6.214940744976818e-05+0j) \epsilon_r(v)=(0.000837707457536069+0j)$
# $\sigma_i=136$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.266517100745574-2.1967203120155294j)  \epsilon_r=(0.008846321770396135+0j) \epsilon_r(\omega)=2.287630674706833e-05  \epsilon_r(p)=(0.0040403334478519674+0j) \epsilon_r(v)=(0.02247575555658937+0j)$
# Computing for sigma_i = 137.00 (quadratic)
# $\sigma_i=137$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.566505340182056-2.1972055526662375j)  \epsilon_r=(0.0003036835558371536+0j) \epsilon_r(\omega)=1.0665693943474602e-05  \epsilon_r(p)=(6.279593480891455e-05+0j) \epsilon_r(v)=(0.0008375890387590717+0j)$
# $\sigma_i=137$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.26651784121206-2.1967204161637186j)  \epsilon_r=(0.00884616848132307+0j) \epsilon_r(\omega)=2.288863079966751e-05  \epsilon_r(p)=(0.004039989681675473+0j) \epsilon_r(v)=(0.022475627131494074+0j)$
# Computing for sigma_i = 138.00 (quadratic)
# $\sigma_i=138$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.566506800958695-2.1972059470765553j)  \epsilon_r=(0.0003038969912767779+0j) \epsilon_r(\omega)=1.0774854726673718e-05  \epsilon_r(p)=(6.344450720992095e-05+0j) \epsilon_r(v)=(0.0008374716118937391+0j)$
# $\sigma_i=138$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.266518581740975-2.19672052042185j)  \epsilon_r=(0.008846015179094072+0j) \epsilon_r(\omega)=2.290095802496256e-05  \epsilon_r(p)=(0.004039645874874906+0j) \epsilon_r(v)=(0.022475498704382348+0j)$
# Computing for sigma_i = 139.00 (quadratic)
# $\sigma_i=139$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.566508263645952-2.197206347213408j)  \epsilon_r=(0.00030411153038346645+0j) \epsilon_r(\omega)=1.0884302738706313e-05  \epsilon_r(p)=(6.409509903953275e-05+0j) \epsilon_r(v)=(0.0008373551893721603+0j)$
# $\sigma_i=139$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.266519322311005-2.1967206248716535j)  \epsilon_r=(0.00884586186590831+0j) \epsilon_r(\omega)=2.2913287329553697e-05  \epsilon_r(p)=(0.004039302025496742+0j) \epsilon_r(v)=(0.022475370284898637+0j)$
# Computing for sigma_i = 140.00 (quadratic)
# $\sigma_i=140$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.566509728211422-2.1972067531016j)  \epsilon_r=(0.0003043271676942215+0j) \epsilon_r(\omega)=1.0994035162622595e-05  \epsilon_r(p)=(6.474768608945662e-05+0j) \epsilon_r(v)=(0.0008372397818305852+0j)$
# $\sigma_i=140$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.26652006289849-2.196720729583999j)  \epsilon_r=(0.008845708544740614+0j) \epsilon_r(\omega)=2.2925617674507812e-05  \epsilon_r(p)=(0.004038958134124012+0j) \epsilon_r(v)=(0.022475241882423322+0j)$
# Computing for sigma_i = 141.00 (quadratic)
# $\sigma_i=141$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.566511194623597-2.1972071647574714j)  \epsilon_r=(0.00030454389787787784+0j) \epsilon_r(\omega)=1.1104049400103968e-05  \epsilon_r(p)=(6.540224595296326e-05+0j) \epsilon_r(v)=(0.0008371253982805664+0j)$
# $\sigma_i=141$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.26652080347961-2.196720834619431j)  \epsilon_r=(0.008845555218858166+0j) \epsilon_r(\omega)=2.2937948108833597e-05  \epsilon_r(p)=(0.004038614202842497+0j) \epsilon_r(v)=(0.02247511350562317+0j)$
# Computing for sigma_i = 142.00 (quadratic)
# $\sigma_i=142$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.56651266285243-2.197207582187633j)  \epsilon_r=(0.0003047617157458832+0j) \epsilon_r(\omega)=1.1214343111236063e-05  \epsilon_r(p)=(6.605875827894077e-05+0j) \epsilon_r(v)=(0.0008370120458474729+0j)$
# $\sigma_i=142$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.26652154403407-2.196720940030434j)  \epsilon_r=(0.008845401891006868+0j) \epsilon_r(\omega)=2.295027781622104e-05  \epsilon_r(p)=(0.004038270233340364+0j) \epsilon_r(v)=(0.022474985161864018+0j)$
# Computing for sigma_i = 143.00 (quadratic)
# $\sigma_i=143$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.566514132869152-2.1972080053933767j)  \epsilon_r=(0.00030498061629075177+0j) \epsilon_r(\omega)=1.1324914143920095e-05  \epsilon_r(p)=(6.671720419327433e-05+0j) \epsilon_r(v)=(0.0008368997305350609+0j)$
# $\sigma_i=143$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.26652228453868-2.196721045863492j)  \epsilon_r=(0.00884524856468918+0j) \epsilon_r(\omega)=2.2962605981209986e-05  \epsilon_r(p)=(0.004037926229392862+0j) \epsilon_r(v)=(0.022474856858693475+0j)$
# Computing for sigma_i = 144.00 (quadratic)
# $\sigma_i=144$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.566515604643932-2.1972084343705705j)  \epsilon_r=(0.000305200594335938+0j) \epsilon_r(\omega)=1.1435760342555674e-05  \epsilon_r(p)=(6.73775651326688e-05+0j) \epsilon_r(v)=(0.0008367884575325895+0j)$
# $\sigma_i=144$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.26652302496867-2.196721152156497j)  \epsilon_r=(0.008845095243978593+0j) \epsilon_r(\omega)=2.2974931835526578e-05  \epsilon_r(p)=(0.004037582196706148+0j) \epsilon_r(v)=(0.022474728603394105+0j)$
# Computing for sigma_i = 145.00 (quadratic)
# $\sigma_i=145$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.566517078149028-2.1972088691097706j)  \epsilon_r=(0.00030542164494382453+0j) \epsilon_r(\omega)=1.1546879782584728e-05  \epsilon_r(p)=(6.803982424549487e-05+0j) \epsilon_r(v)=(0.0008366782308033941+0j)$
# $\sigma_i=145$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.26652376530369-2.1967212589447462j)  \epsilon_r=(0.008844941932070076+0j) \epsilon_r(\omega)=2.2987254713105177e-05  \epsilon_r(p)=(0.004037238139378138+0j) \epsilon_r(v)=(0.022474600402118985+0j)$
# Computing for sigma_i = 146.00 (quadratic)
# $\sigma_i=146$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.56651855335747-2.197209309597597j)  \epsilon_r=(0.0003056437632545923+0j) \epsilon_r(\omega)=1.1658270648090467e-05  \epsilon_r(p)=(6.870396559609783e-05+0j) \epsilon_r(v)=(0.0008365690535195886+0j)$
# $\sigma_i=146$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.26652450552001-2.1967213662581146j)  \epsilon_r=(0.008844788633012874+0j) \epsilon_r(\omega)=2.299957393500147e-05  \epsilon_r(p)=(0.004036894063764615+0j) \epsilon_r(v)=(0.022474472261339005+0j)$
# Computing for sigma_i = 147.00 (quadratic)
# $\sigma_i=147$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.566520030241668-2.197209755817698j)  \epsilon_r=(0.0003058669442924617+0j) \epsilon_r(\omega)=1.1769931108428573e-05  \epsilon_r(p)=(6.936997338327958e-05+0j) \epsilon_r(v)=(0.000836460928385677+0j)$
# $\sigma_i=147$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.26652524559419-2.196721474121993j)  \epsilon_r=(0.008844635350923537+0j) \epsilon_r(\omega)=2.3011888866438245e-05  \epsilon_r(p)=(0.004036549976726677+0j) \epsilon_r(v)=(0.022474344187177493+0j)$
# Computing for sigma_i = 148.00 (quadratic)
# $\sigma_i=148$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.566521508776587-2.1972102077515365j)  \epsilon_r=(0.00030609118343147604+0j) \epsilon_r(\omega)=1.1881859555428868e-05  \epsilon_r(p)=(7.003783334412655e-05+0j) \epsilon_r(v)=(0.0008363538573948727+0j)$
# $\sigma_i=148$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.266525985503336-2.1967215825586006j)  \epsilon_r=(0.00884448208987499+0j) \epsilon_r(\omega)=2.3024198910425086e-05  \epsilon_r(p)=(0.004036205885311333+0j) \epsilon_r(v)=(0.022474216185403212+0j)$
# Computing for sigma_i = 149.00 (quadratic)
# $\sigma_i=149$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.566522988935477-2.1972106653768804j)  \epsilon_r=(0.0003063164757228048+0j) \epsilon_r(\omega)=1.1994054276510321e-05  \epsilon_r(p)=(7.070753080608444e-05+0j) \epsilon_r(v)=(0.0008362478420858196+0j)$
# $\sigma_i=149$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.266526725224864-2.1967216915876153j)  \epsilon_r=(0.008844328853933919+0j) \epsilon_r(\omega)=2.303650349753091e-05  \epsilon_r(p)=(0.0040358617967770705+0j) \epsilon_r(v)=(0.022474088261527154+0j)$
# Computing for sigma_i = 150.00 (quadratic)
# $\sigma_i=150$
# $[Closest to \omega=(12.566370614359172-2.197224577336219j)] idx=0  \omega=(12.566524470694064-2.197211128671499j)  \epsilon_r=(0.0003065428166018144+0j) \epsilon_r(\omega)=1.2106513751040256e-05  \epsilon_r(p)=(7.137905237655038e-05+0j) \epsilon_r(v)=(0.0008361428836778527+0j)$
# $\sigma_i=150$
# $[Closest to \omega=(50.26548245743669-2.197224577336219j)] idx=0  \omega=(50.26652746473554-2.196721801225899j)  \epsilon_r=(0.008844175647389927+0j) \epsilon_r(\omega)=2.3048802071238673e-05  \epsilon_r(p)=(0.0040355177190817835+0j) \epsilon_r(v)=(0.02247396042101676+0j)$

# %%
import numpy as np

np.savez(
    f"results_sigma_optimization_{pml_profile}.npz",
    pml_thickness=pml_thickness,
    Lx=Lx,
    l_inner=l_inner,
    rho_media_1=rho_media_1,
    rho_media_2=rho_media_2,
    vel_media_1=vel_media_1,
    vel_media_2=vel_media_2,
    sigma_sweep=sigma_sweep,
    rel_err_eig_sigma_sweep=rel_err_eig_sigma_sweep,
    rel_err_p_sigma_sweep=rel_err_p_sigma_sweep,
    rel_err_v_sigma_sweep=rel_err_v_sigma_sweep,
    rel_err_total_sigma_sweep=rel_err_total_sigma_sweep,
    h=h,
    N=np.array(N),
    # exact_p=exact_p,
    # exact_v=exact_v,
    exact_omega=exact_omega,
    # approx_p_values=approx_p.x.array,
    # approx_v_values=approx_v.x.array,
    approx_omega=approx_omega,
)

# %%
linestyles = {0: '--', 3: ':'}
markers= {0: 'x', 3: 'o'}
labels = {0: r'$\omega_0$', 3: r'$\omega_3$'}

match pml_profile:
    case "constant":
        uppercase_name="Constant"
    case "quadratic":
        uppercase_name="Quadratic"
    case "singular":
        uppercase_name="Singular"


fig, ax = plt.subplots(figsize=(8, 6))
err_tot = rel_err_total_sigma_sweep

for j in [0, 3]:            # modos físicos
    for i, N_index in enumerate(N):
        col = colors_list[i % len(colors_list)]
        ls = linestyles[j]

        errs = err_tot[j][N_index]

        ax.plot(
            sigma_sweep,
            errs,
            color=col,
            linestyle=ls,
            label=rf"{labels[j]}, $N={N_index}$"
        )

        # mínimo
        k = np.argmin(errs)
        ax.plot(
            sigma_sweep[k],
            errs[k],
            markers[j],
            color=col,
            markersize=8,  markerfacecolor='none'
                )

ax.set_yscale('log')
ax.set_xlabel(f'$\sigma_0$ - {uppercase_name} profile')
ax.set_ylabel(r'Relative error [\%]')
ax.grid(True)
ax.set_xlim([sigma_sweep[0], sigma_sweep[-1]])
# lenda sen duplicados
handles, labels_leg = ax.get_legend_handles_labels()
by_label = dict(zip(labels_leg, handles))
ax.legend(by_label.values(), by_label.keys(), ncol=2, loc='upper right')
ax.set_ylim([10e-3,10e3])
# plt.suptitle(
#     f'$\sigma_0$ optimization depending on $\omega$ and N values. PML profile {pml_profile}.',
#     fontsize=14
# )

plt.tight_layout()
# plt.savefig(f"sigma_optimization_total_{pml_profile}.png", dpi=300)
plt.savefig(f"1D_bicapa_optimo_{pml_profile}.pdf", dpi=300)

plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
eig_number=0  # modo físico 0
N_i=N[0]         # refinamento N=4 (0,1,2 → 2,3,4)

sigma_of_interest=1
indice = np.argmin(np.abs(sigma_sweep - sigma_of_interest))
print("Sigma of interest: ", sigma_sweep[indice])
print("Relative error total: ", rel_err_total_sigma_sweep[eig_number][N_i][indice])

sigma_0=sigma_sweep[indice]

idx_min_err = np.argmin(rel_err_total_sigma_sweep[eig_number][N_i])
p_approx = approx_p[eig_number][N_i][indice]
v_approx = approx_v[eig_number][N_i][indice]
p_exact = exact_p[eig_number][N_i][indice]
v_exact = exact_v[eig_number][N_i][indice]

mesh = create_interval(MPI.COMM_WORLD, int((Lx + pml_thickness) / h[N_i]), [0, Lx + pml_thickness])

bb = bb_tree(mesh, mesh.topology.dim)

# Extract FunctionSpace objects from the approximated functions
Q = p_approx.ufl_function_space()
V = v_approx.ufl_function_space()

fig, axes = plt.subplots(1, 2, figsize=(12,8))
# --- p, modo 0 ---
ax = axes[0]
xx = np.linspace(0, Lx+pml_thickness, 100)
yy = [eval_point_fast(p_exact, bb, x, mesh) for x in xx]
ax.plot(xx, np.real(yy), label="Re(p)", linestyle="-")
yy = [eval_point_fast(p_approx, bb, x, mesh) for x in xx]
ax.plot(xx, np.real(yy), label="Re(p)", linestyle="-.")
ax.set_xlabel("x [m]")
ax.set_ylabel("p(x) [Pa]")
ax.grid(True)


ax = axes[1]
xx = np.linspace(0, Lx+pml_thickness, 100)
yy = [eval_point_fast(v_exact, bb, x, mesh) for x in xx]
ax.plot(xx, np.real(yy), label="Re(v)", linestyle="-")        
yy = [eval_point_fast(v_approx, bb, x, mesh) for x in xx]
ax.plot(xx, np.real(yy), label="Re(v)", linestyle="-.")
ax.set_xlabel("x [m]")
ax.set_ylabel("v(x) ")
ax.grid(True)
fig.suptitle("Sigma {pml_profile} - Modo {eig}, N={N_i}, sigma={sigma_0}".format(pml_profile=pml_profile, eig=eig_number, N_i=N_i, sigma_0=sigma_0))
plt.show()
